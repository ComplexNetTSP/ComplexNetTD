# %% [markdown]
# <h1 align="center">TD 1: Introduction to graph theory with Networkx</h3>
#
# <h3 align="center">Vincent Gauthier</h3>
# <h4 align="center">vincent.gauthier@telecom-sudparis.eu</h4>
#
# <img src="./images/webmap.jpg"></img>
#
# # Getting Started
#
# ## Installing Python (Anaconda)
# We recommend using the Anaconda Python distribution, as it bundles together many useful packages (including numpy, matplotlib, and IPython) that we will use throughout this class. To install Anaconda, please see [here](http://docs.continuum.io/anaconda/install). Make sure you get the version compatible with your OS (Mac, Linux, or Windows). If you'd like a more comprehensive document, please check out CS109's guide [here](https://github.com/cs109/content/wiki/Installing-Python).
#
# ## Python Shell
# The Python Interactive Shell is a light-weight way to explore Python. It's commonly used for debugging, quick tasks, and as a calculator! To get to the shell, open Terminal and type `python`. More instructions are located [here](https://docs.python.org/2/tutorial/interpreter.html). The following sections will be done in the shell to allow you to get a feel for Python.
#
# # Python Basic
# ## Lists
#
# Lists are basic Python structures that function as arrays. They can store all types of data. You can index a specific element using `[]` brackets, which comes in handy very frequently.

# %%
# Style pour le Notebook
from IPython.core.display import HTML

def css_styling():
    styles = open("./styles/custom.css", "r").read()
    return HTML(styles)
css_styling()
# Out:
# <style>
#     div.cell{
#       width:800px;
#       margin-left:16% !important;
#       margin-right:auto;
#     }
#
#     h1,h2,h3,h4,h5 {
#       align: left;
#       font-family:"Charis SIL", serif;
#     }
#
#     div.text_cell_render{
#       width:800px;
#       font-family: "Charis SIL", sans-serif;
#       line-height: 145%;
#       font-size: 145%;
#       line-height: 145%;
#     }
#
#     .CodeMirror{
#       font-family: "Source Code Pro", monospace;
#     }
#
#     .prompt{
#       display: None;
#     }
#
#     .text_cell_render h5 {
#       font-weight: 300;
#       font-size: 22pt;
#       color: #4057A1;
#       font-style: italic;
#       margin-bottom: .5em;
#       margin-top: 0.5em;
#       display: block;
#     }
#
#     div.warn {
#       margin-top: 30px;
#       background-color: #fcf2f2;
#       border-color: #dFb5b4;
#       border-left: 5px solid #dfb5b4;
#       padding: 0.5em;
#     }
#
#     div.green {
#       margin-top: 30px;
#       background-color: #adf08d;
#       border-color: #34c123;
#       border-left: 5px solid #34c123;
#       padding: 0.5em;
#     }
#
# </style>
# <script>
#     MathJax.Hub.Config({
#       TeX: {
#         extensions: ["AMSmath.js"],
#         //equationNumbers: { autoNumber: "AMS" , useLabelIds: false}
#       },
#       tex2jax: {
#         inlineMath: [ ['$','$'], ["\\(","\\)"] ],
#         displayMath: [ ['$$','$$'], ["\\[","\\]"] ],
#         processEscapes: true,
#         processEnvironments: true
#       },
#       displayAlign: 'center',
#       "HTML-CSS": {
#         styles: {'.MathJax_Display': {"margin": 4}}
#       }
#     });
# </script>

# %%
# Variable assignment
a = 3
b = 2
print(a + b)  # 5

c = []
d = [1,2]

# %%
# List basics
print('List basics:')
list_a = []
list_b = [1,2,3,4,5,6]
print('list b:', list_b)
second_elt_in_list_b = list_b[1]  # remember, we index from 0
print('second element in list b:', second_elt_in_list_b)
tmp = [1,3,4]
sub_list_list_b = [list_b[i] for i in tmp]
print('sub list:', sub_list_list_b)
list_b.append(7)
print('new list b:', list_b)
last_elt_b = list_b[-1]
last_elt_b_2 = list_b[len(list_b)-1]
print('last element two ways:', last_elt_b, last_elt_b_2)
print('\n')  # newline character

# List of lists
print('List of lists:')
list_of_lists_c = [list_a,list_b]
print('list of lists c:', list_of_lists_c)
list_of_lists_c.append([3,4,5])
print('new list of lists c:', list_of_lists_c)
third_list_in_c = list_of_lists_c[2]
print('third list in c:', third_list_in_c)
second_elt_of_third_list_in_c = list_of_lists_c[2][1]
print('second element of third list in c:', second_elt_of_third_list_in_c)
print('\n')

# %% [markdown]
# ## Conditional Statements
#
# Conditional statements and loops are useful control structures that allow you to structure the way your program will execute. Note that Python cares about whitespace; proper indentation after conditional statements and function definitions (in the next section) is key to avoiding syntax errors, even in the Interactive Shell.

# %%
# Conditional statements
if 1 > 0:
    print('1 > 0')
    
if 1 < 0:
    print('1 < 0')
else:
    print('1 !< 0')
    
if 1 < 0:
    print('1 < 0')
elif 1 < 2:
    print('1 < 2')
else:
    print('none of the above')

# %% [markdown]
# ## Loops

# %%
# For loops
for i in range(0,10):
    print(i)
    
# looping through lists
for x in list_b:
    print(x)

# While loops
j = 0
while j < 10:
    print(j)
    j += 1

# %% [markdown]
# ### List comprehensions

# %%
# List comprehensions
list_b = [1,3,4,2,5,6,4,5,7,5,6,4,5,3,1,2]

# Normal for loop
tmp1 = []
for x in list_b:
    if x > 3:
        tmp1.append(x)
print('Normal for loop:', tmp1)

# List comprehension
tmp2 = [x for x in list_b if x > 3]
print('List comprehension:', tmp2)

# %%
# Using LL from the previous example, do the following:
# Given a list of lists, do the following:
LL = [[1,2],[2,3],[3,4,5],[4,5,6,7],[5,6],[6,7,8,8,9]]

# a. Create a new list first_LL of the first elements of each sublist
first_LL = []
for L in LL:
    first_LL.append(L[0])
    
print(first_LL)

# b. Create a new list last_LL of the last elements of each sublist
last_LL = []
for L in LL:
    last_LL.append(L[-1])  # or L[len(L)-1]
    
print(last_LL)

# c. Print all values in all sublists in the range [4,8]
for L in LL:
    for x in L:
        if x >= 4 and x <= 8:
            print(x)

# d. Print all sublists of length 3 or greater
for L in LL:
    if len(L) >= 3:
        print(L)

# %%
# Checking membership

# Lists
list_d = [1,2,3,4,5]

if 1 in list_d:
    print('1 is in list d')

if 6 not in list_d:
    print('6 is not in list d')

# %% [markdown]
# ## Dictionaries
#
# In Python, dictionaries are essentially hash tables. They store (key,value) pairs and can contain data of all types.

# %%
# Dictionary example
my_dict = {}  # declare empty dictionary
my_dict['key1'] = 'value1'  # insert ('key1','value1') pair in dictionary
print('my dict:', my_dict)  # prints entire dictionary
print('first entry:', my_dict['key1'])  # index into dictionaries with keys

# Second dictionary example
dict1 = {}
for x in range(1,21):
    # each dictionary entry is a list of all whole numbers less than that value
    dict1[x] = list(range(0,x))
print('list dict:', dict1)
print('last entry:', dict1[20])

# %%
# Dictionaries
# dict.keys() and dict.values() are lists of the keys and values in the dictionary
dict_a = {'a': 3, 'b': 2, 'c': 1}

if 'a' in dict_a.keys():
    print('a is a key in dict a')
if 'd' not in dict_a.keys():
    print('d is not a key in dict a')
    
if 3 in dict_a.values():
    print('3 is a value in dict a')
if 4 not in dict_a.values():
    print('4 is not a value in dict a')

# %% [markdown]
# ## Functions
#
# Functions are useful ways of encapsulating blocks of code to perform tasks. Each function is declared with the `def` keyword and takes a list of arguments. Additionally, most functions return something via the `return` keyword, which exits the function.

# %%
# Functions are declared with the 'def' keyword followed by the 
# function name and a list of arguments to the function.
def my_function(arg1,arg2):
    tmp = arg1 + arg2
    return tmp

return_value = my_function(1,3)
print('sum:', return_value)

def sum_list_naive(L):
    sum = 0
    for x in L:
        sum += x
    return sum

print('sum list:', sum_list_naive([1,4,5,3]))

# %% [markdown]
# ### Exercises 1
#
# Write a function that goes through the following list and finds the smallest element. Do not use any built-in functions such as min(L).

# %%
# Find the smallest element of this list
L = [3,1,2,4,5,3,1,4,2,5,6,3,6,7,5,4,7,1,2,4,3,5,6,7,5]

# Pseudocode:
# Initialize current smallest element to the first element in list
# Loop through list, updating current smallest element if necessary

def find_smallest(input_list):
    # your code

L_smallest = find_smallest(L)
print(L_smallest)

# %% [markdown]
# # Representing Graphs
#
# The most common data structures for representing graphs are adjacency matrices and adjacency lists. In general, adjacency matrices are better for dense graphs (because they take up $O(n^2)$ room), and they support very quick edge lookups. However, it's slow to iterate over all edges. Adjacency lists are better for sparse graphs and allows quick iteration over all edges in a graph, but finding the existence of a specific edge takes longer. For these examples, we will focus on using adjacency lists.
#
# The most basic way of representing a graph is through a list of lists. In this way, we can say that the $n^{th}$ list represents all of the $n^{th}$ vertex's connections. We will go through an example on the board.

# %%
# List of lists representation of a graph
# Graph G: Vertices = {0,1,2,3}, Edges = {(0,1),(1,2),(2,3),(3,0)}

G_LL = [[1,3],[0,2],[1,3],[0,2]]

# Vertex 0's neighbors
print(G_LL[0])

# Vertex 1's neighbors
print(G_LL[1])

# %% [markdown]
# Another way of representing a graph is through a dictionary. See the below section for a quick introduction to a dictionary. The keys in this case will be the vertex names, and the corresponding values will be a list of all adjacent vertices. Note that using a dictionary is more convenient for graphs that have strings as labels for each vertex, but using a dictionary is more expensive in terms of memory and time. For the example above, we have the following.

# %%
# Dictionary representation of a graph
# Graph G: Vertices = {0,1,2,3}, Edges = {(0,1),(1,2),(2,3),(3,0)}

G_dict = {0:[1,3], 1:[0,2], 2:[1,3], 3:[0,2]}

# Vertex 0's neighbors
print(G_dict[0])

# Vertex 1's neighbors
print(G_dict[1])

# %% [markdown]
# # Plotting Data

# %%
# %matplotlib nbagg

import matplotlib.pylab as plt  # use matplotlib's pyplot package

plt.plot([1,3,4],[3,6,7])  # plt.plot draws a line
plt.show()

# %% [markdown]
# # Matrix Operations in Python
#
# When dealing with matrices in Python, the general best practice is to use the NumPy package. This codelab will go over how to carry out operations on matrices useful for the next problem set (and in general).

# %%
import numpy as np
# numpy has packages called 'matrix' and 'linalg' that will be useful

mat1 = np.matrix( [[1.,2.,3.],[4.,5.,6.],[7.,8.,9.]] )
mat2 = np.matrix( [[0,1,0],[1,0,0],[0,1,1]] )

print('matrices: \n', mat1, '\n', mat2)

# indexing into matrices
print('first row:\n', mat1[0,:])
print('first column:\n', mat1[:,0])
print('first two rows:\n', mat1[0:2,:])
print('first two cols:\n', mat1[:,0:2])

# matrix attributes
print('shape: ', mat1.shape)
print('size: ', mat1.size)

# %% [markdown]
# Here are some matrix operations that you should know: (useful link here: http://sebastianraschka.com/Articles/2014_matlab_vs_numpy.html)

# %%
# matrix operations
print ('plus: \n', mat1 + mat2)
print ('minus: \n', mat1 - mat2)

# element-wise multiplication
print ('element-wise multiplication: \n', np.multiply(mat1,mat2))

# matrix multiplication
print('matrix multiplication: \n', np.dot(mat1,mat2))
# print mat1*mat2

# element-wise division
print('element-wise division: \n', np.divide(mat2,mat1))
# print mat2/mat1

# raising matrices to powers (element-wise)
print('element-wise power: \n', np.power(mat1,2))

# raising matrices to powers
print('matrix power: \n', np.linalg.matrix_power(mat1,2))

# %% [markdown]
# # Breadth First Search
#
# Breadth first search (BFS) is a common and useful graph traversal algorithm. A graph traversal algorithm describes a process for visiting the nodes in a tree or graph, where traversing from one node to another is only allowed if there is an edge connecting those vertices. A motivational property of BFS is that it can find connectivity and shortest distances between two nodes in graphs. For this class, we will apply BFS to compute centrality measures and other graph properties. In this lab we will study how BFS runs, how to implement it, and how it can be used.
#
# ### Queue
# Before we can begin to study BFS, we need to understand the queue data structure. Similar to the non-computer science understanding of the word, a queue is essentially a line. Data, in our case nodes or vertices, enter the queue and are stored there. The operation of adding data to a queue is called enqueue() or push(). The order in which they enter the queue is preserved. When we need to retrieve data, we take the earliest element from the queue and it is removed from the queue. This operation is called dequeue() or pop(). This is referred to as <i>first-in-first-out</i> (FIFO).
#
# In Python, we can implement a queue naively as a list. However, lists were not built for this purpose, and do not have efficient push() and pop() operations. Alternatives include implementations included in libraries (which we will be using) or defining your own class and operations. For this lab we will use the queue data structure from the 'collections' library (https://docs.python.org/2/library/collections.html#collections.deque).

# %%
from collections import deque

# %%
# initializes the queue with [S, W, M]
queue = deque(["Scarlet", "White", "Mustard"])
queue.append("Plum")
# Now the queue is [S, W, M, P]
queue.popleft()
# Now the queue is [W, M, P]
queue.append("Greene")
# etc
queue.popleft()
queue.popleft()
murderer = queue.popleft()

# who is Boddy's murderer?
# ANSWER: Plum

# %% [markdown]
# ### Algorithm

# %% [markdown]
# Recall that a graph traversal is a route of nodes to follow or traverse, where we can only move between two nodes if there is an edge between them. Breadth first search specifies a process for doing so. In the simplest implementation, BFS visits a given node, adds its neighbors to the queue, then visits the element returned by the queue. To begin the BFS, we start at a given node, then visit all of that node's nieghbors, then visit all of one neighbor's neighbors, then another neighbor's neighbors, etc. Whenever we visit a node for the first time, we mark it as visited; otherwise we do nothing when re-visiting a node. The algorithm terminates once we have visited everything reachable from the given node, and we have a list of nodes reachable from that node.
#
# <br />
# <div align="center">
# <img width=400 src="Images/BFS.png"></img>
# **Algorithm 1.: BFS**
# </div>

# %%
# graph G represented as an adjacency list dictionary, a node v to start at
def simpleBFS(G, v):
    reachable = [-1] * len(G.keys())   # -1 indicates unvisited
    reachable[v-1] = 1                 # note: we assume vertices have integer names
    
    queue = deque()
    queue.append(v)
    while len(queue) != 0:           # while we still have things to visit
        current = queue.popleft()
        for node in G[current]:
            if reachable[node-1] == -1:
                reachable[node-1] = 1
                queue.append(node)
    
    return reachable

# %%
# G as an adjacency list
G = {1:[2,3], 2:[5], 3:[4], 4:[], 5:[2,3], 6:[5]}

# %%
simpleBFS(G, 1)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-4-effc76da2feb> in <module>()
# ----> 1 simpleBFS(G, 1)
#
# <ipython-input-2-3bffe9152605> in simpleBFS(G, v)
#       4     reachable[v-1] = 1                 # note: we assume vertices have integer names
#       5
# ----> 6     queue = deque()
#       7     queue.append(v)
#       8     while len(queue) != 0:           # while we still have things to visit
#
# NameError: name 'deque' is not defined

# %% [markdown]
# <div align="center"> <img width=500 src="images/SimpleGraph.png"></img> </div>
#
#
# all the graph above $G$. If we call simpleBFS($G$, $a$), the steps the BFS will take are (assume nodes are added to the queue in alphabetical order)
# 1. start at $a$, push nodes $b$ and $c$ on the queue and mark them as visited
# 2. pop off $b$ from the queue, visit it, and add $e$ to the queue
# 4. pop off $c$ from the queue, visit it, and add $d$ to the queue
# 4. pop off $e$ from the queue, upon seeing that $c$ and $b$ have been visited, no nodes are added to the queue
# 5. pop off $d$ from the queue, no nodes are added to the queue
# 6. queue is now empty, simpleBFS terminates and returns a list from which we can iterate through and see that only $f$ is not reachable from $a$
#
# ## Exercises:
# **Question**: What is the order of traversal for simpleBFS($G$, $f$)? simpleBFS($G$,$b$)?
#
# **Result**:
#
# ### Modifications
# Armed with an understanding of how BFS operates, we can make improvements on the algorithm so that we can extract more information about the graph in the running of BFS. Consider the following:

# %%
# graph G represented as an adjacency list dictionary, a node v to start at
def distBFS(G, v):
    dist = [-1] * len(G.keys())
    dist[v-1] = 0                 # the distance from v to itself is 0
    
    queue = deque()
    queue.append(v)
    while len(queue) != 0:           # while we still have things to visit
        current = queue.popleft()
        for node in G[current]:
            if dist[node-1] == -1:
                dist[node-1] = dist[current-1] + 1
                queue.append(node)
    
    return dist

# %%
print(distBFS(G, 1))
# Out:
# [0, 1, 1, 2, 2, -1]

# %% [markdown]
# With this implementation of BFS, we not only are able to find out which vertices of the graph are reachable from $v$, but also how far away (in terms of nodes in between) each vertex is from $v$. Moreover, the path length returned by distBFS() is provably the shortest path from $v$ to any other vertex in $G$, provided there are no edge weights associated with the graph. However, even if we know the shortest path, it would be nice to know which nodes precisely we would need to traverse to get from $v$ to that vertex. We can still do that with BFS. Consider the following:

# %%
# graph G represented as an adjacency list dictionary, a node v to start at
def BFS(G, v):
    dist = [-1] * len(G.keys())       
    prev = [None] * len(G.keys())
    dist[v-1] = 0                     
    
    queue = deque()
    queue.append(v)
    while len(queue) != 0:
        current = queue.popleft()
        for node in G[current]:
            if dist[node-1] == -1:
                dist[node-1] = dist[current-1] + 1
                prev[node-1] = current
                queue.append(node)
    
    return dist, prev

# %%
print(BFS(G,1))
# Out:
# ([0, 1, 1, 2, 2, -1], [None, 1, 1, 3, 2, None])

# %% [markdown]
# With this implementation of BFS, we introduce the prev array, which for a given node $w$ keeps track of the node that we visited that led us to that node. This node is a <i>predecessor</i> of $w$. Returned this information, if we want to find the path from $v$ to $w$, first inspect the dist array to make sure $w$ is reachable from $v$. If it is reachable, we simply inspect the prev array for prev[w]. If that is not $v$, we look for the predecessor of prev[w], and on until we find $v$.
#
# ### Exercice
#
# - Walk through BFS(G,B) on the graph above, keeping track of the order visited and the state of the arrays. (We will use the following format: current node, dist, prev):
#
#     * B
#     * E
#     * C
#     * D
#
# **Result:**

# %% [markdown]
# ## Compute Clustering
#
# Recall that the clustering coefficient $C(v)$ of a vertex $v$ is the fraction over all pairs of neighbors of $v$ of pairs between which an edge exists. In real world social networks we usually see high clustering, and therefore we want our random graph models to also have this property. Ultimately we want to find the clustering coefficient of the graph, but we begin by calculating the clustering coefficient for a single vertex.

# %%
def vertexCC(G,v):
    v_neighbors = G[v]
    edges = 0.0
    for i in range(len(v_neighbors)):
        for j in range(i+1, len(v_neighbors)):
            if v_neighbors[j] in G[v_neighbors[i]]:
                edges += 1
    return edges / ((len(v_neighbors)^2 - len(v_neighbors))/2)

# %%
'''
Use vertexCC() to calculate the clustering coefficient of the entire graph, 
which is the average clustering coefficient of its nodes.
'''

def graphCC():
    ### "TODO"
# Out:
#   File "<ipython-input-1-b2258eebd93c>", line 7
#     ### "TODO"
#               ^
# SyntaxError: unexpected EOF while parsing

# %% [markdown]
# # Networkx
#
# ## Overview
# NetworkX is a Python language software package for the creation, manipulation, and study of the structure, dynamics, and function of complex networks.
#
# With NetworkX you can load and store networks in standard and nonstandard data formats, generate many types of random and classic networks, analyze network structure, build network models, design new network algorithms, draw networks, and much more.
#
# ## Who uses NetworkX?
# The potential audience for NetworkX includes mathematicians, physicists, biologists, computer scientists, and social scientists.
#
# ## Goals
# NetworkX is intended to provide tools
#
# * tools for the study of the structure and dynamics of social, biological, and infrastructure networks,
# * a standard programming interface and graph implementation that is suitable for many applications,
# * a rapid development environment for collaborative, multidisciplinary projects,
# * an interface to existing numerical algorithms and code written in C, C++, and FORTRAN,
# * the ability to painlessly slurp in large nonstandard data sets
#
# for more information fo to the [Networkx Documentation](http://networkx.github.io/documentation/latest/index.html)

# %%
import networkx as nx
# %matplotlib nbagg

# %%
G = nx.Graph()

G.add_node(1)
G.add_node(2)
G.add_node(3)
G.add_node(4)
G.node[1]['name'] = 'Paul'
G.node[2]['name'] = 'Pierre'
G.node[3]['name'] = 'Sophie'
G.node[4]['name'] = 'Caroline'

G.add_edge(1,2)
G.add_edge(2,3)
G.add_edge(3,4)

nx.draw_networkx(G)
# Out:
# <img src="data:image/png;base64,...">

# %% [markdown]
# ## We load the graph of the Florentine Families

# %%
import csv
import networkx as nx

with open('Data/Florence/FlorentineFamiliesName.csv', 'r') as csvfile:
    nodeReader = csv.reader(csvfile, delimiter=' ')
    line = 0
    labels = {}
    for row in nodeReader:
        if line > 0:
            labels[int(row[0])] = row[1]
        line += 1


# Create the graph
G = nx.Graph()
with open('Data/Florence/FlorentineFamiliesNodes.csv', 'r') as csvfile:
    nodeReader = csv.reader(csvfile, delimiter=' ')
    line = 0
    for row in nodeReader:
        G.add_node(int(row[1]),label=labels[int(row[1])])
        G.add_node(int(row[2]),label=labels[int(row[2])])
        G.add_edge(int(row[1]),int(row[2]), weigth=float(row[3]))

# %% [markdown]
# ## Plot the Graph of the Florentine Families with labels
#
# [Plotting Graph with networkx](https://networkx.github.io/documentation/latest/reference/generated/networkx.drawing.nx_pylab.draw_networkx.html#networkx.drawing.nx_pylab.draw_networkx)

# %%
pos=nx.spring_layout(G)
nx.draw_networkx_nodes(G,pos,
                       node_color='r',
                       node_size=500,
                       alpha=0.8)

nx.draw_networkx_edges(G,pos,width=1.0,alpha=0.5)
nx.draw_networkx_labels(G,pos,labels,font_size=9)

plt.axis('off')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-5-e5391fb897ec> in <module>()
#       6
#       7 nx.draw_networkx_edges(G,pos,width=1.0,alpha=0.5)
# ----> 8 nx.draw_networkx_labels(G,pos,labels,font_size=9)
#       9
#      10 plt.axis('off')
#
# /usr/local/anaconda/lib/python3.4/site-packages/networkx/drawing/nx_pylab.py in draw_networkx_labels(G, pos, labels, font_size, font_color, font_family, font_weight, alpha, bbox, ax, **kwds)
#     721     text_items = {}  # there is no text collection so we'll fake one
#     722     for n, label in labels.items():
# --> 723         (x, y) = pos[n]
#     724         if not cb.is_string_like(label):
#     725             label = str(label)  # this will cause "1" and 1 to be labeled the same
#
# KeyError: 12

# %% [markdown]
# ## Compute the closeness centrality of the graph

# %%
# TODO

# %% [markdown]
# ## Plot the graph with de node size as function of the closeness centrality

# %%
# TODO

# %% [markdown]
# ## Do the same things with your [Linkedin Network](http://socilab.com/#home) but for the betweeness centrality

# %%
# Todo

# %% [markdown]
# # Actor Network

# %%
import csv
with open('Data/Freebase/freebase_performances.csv', 'r') as csvfile:
    reader = csv.reader(csvfile, delimiter=',')
    line = 0
    data = []
    for row in reader:
        if line > 0:
            data.append(row)
        line += 1
data
# Out:
# [['0',
#   'David A. R. White',
#   'Adam Riley',
#   'The Moment After 2: The Awakening',
#   '2006'],
#  ['1',
#   'Lonnie Colon',
#   "'Captain' Robert Jackson",
#   'The Moment After 2: The Awakening',
#   '2006'],
#  ['2',
#   'Brad Heller',
#   'Jacob Krause',
#   'The Moment After 2: The Awakening',
#   '2006'],
#  ['3', 'Logan White', 'Carissa', 'The Moment After 2: The Awakening', '2006'],
#  ['4',
#   'Monte Perlin',
#   'Commander Fredericks',
#   'The Moment After 2: The Awakening',
#   '2006'],
#  ['5',
#   'John Gilbert',
#   'Peter McCollum',
#   'The Moment After 2: The Awakening',
#   '2006'],
#  ['6',
#   'Kevin Downes',
#   'Charles Baker',
#   'The Moment After 2: The Awakening',
#   '2006'],
#  ['7',
#   'Asad Farr',
#   'Global Chairman',
#   'The Moment After 2: The Awakening',
#   '2006'],
#  ['8',
#   'Don Parker Decker',
#   'President of the United States',
#   'The Moment After 2: The Awakening',
#   '2006'],
#  ['9',
#   'Bree Pavey',
#   'Audrey Thomas',
#   'The Moment After 2: The Awakening',
#   '2006'],
#  ['10', 'John Hawkes', 'Donnie Carson', 'Small Town Saturday Night', '2009'],
#  ['11',
#   'Shawn Christian',
#   'Tommy Carson',
#   'Small Town Saturday Night',
#   '2009'],
#  ['12', 'Chris Pine', 'Rhett Ryan', 'Small Town Saturday Night', '2009'],
#  ['13', 'Bre Blair', 'Samantha Carson', 'Small Town Saturday Night', '2009'],
#  ['14',
#   'Octavia Spencer',
#   'Rhonda Dooley',
#   'Small Town Saturday Night',
#   '2009'],
#  ['15', 'Lin Shaye', 'Phyllis Ryan', 'Small Town Saturday Night', '2009'],
#  ['16',
#   'Brent Briscoe',
#   'Travis Perkins',
#   'Small Town Saturday Night',
#   '2009'],
#  ['17',
#   'Scott Michael Campbell',
#   'Dwayne Murphy',
#   'Small Town Saturday Night',
#   '2009'],
#  ['18', 'Muse Watson', 'Charlie Carson', 'Small Town Saturday Night', '2009'],
#  ['19', 'Adam Hendershott', 'Les Ryan', 'Small Town Saturday Night', '2009'],
#  ['20', 'Kali Majors', 'Megan Carson', 'Small Town Saturday Night', '2009'],
#  ['21', 'Bill McKenzie', 'Herb', 'Small Town Saturday Night', '2009'],
#  ['22', 'Damara Reilly', 'Carla', 'Small Town Saturday Night', '2009'],
#  ['23', 'Mike Lutgen', 'Rodney', 'Small Town Saturday Night', '2009'],
#  ['24', 'Ryan Craig', 'Wade Jefferies', 'Small Town Saturday Night', '2009'],
#  ['25', 'Nicholas Burns', 'Caydern', 'Pendragon: Sword of His Father', '2008'],
#  ['26',
#   'Marilyn Burns',
#   'Wenneveria',
#   'Pendragon: Sword of His Father',
#   '2008'],
#  ['27',
#   'Howard Shepherd',
#   'Regeanhere',
#   'Pendragon: Sword of His Father',
#   '2008'],
#  ['28', 'Erik Dewar', 'Brotus', 'Pendragon: Sword of His Father', '2008'],
#  ['29', 'Brian Ervin', 'Carasseus', 'Pendragon: Sword of His Father', '2008'],
#  ['30',
#   'Adrianne Burns',
#   "Justinian's Wife",
#   'Pendragon: Sword of His Father',
#   '2008'],
#  ['31',
#   'Raymond Burns',
#   'Justinian Pendragon',
#   'Pendragon: Sword of His Father',
#   '2008'],
#  ['32', 'Rebekah Wixom', 'Adria', 'Pendragon: Sword of His Father', '2008'],
#  ['33', 'Wally Patton', 'Hengest', 'Pendragon: Sword of His Father', '2008'],
#  ['34', 'Tim Quinlan', 'Quinlan', 'Pendragon: Sword of His Father', '2008'],
#  ['35', 'Aaron Burns', 'Artos', 'Pendragon: Sword of His Father', '2008'],
#  ['36', 'Cary Annen', 'Saxon Guard', 'Pendragon: Sword of His Father', '2008'],
#  ['37', 'Chad Burns', 'Lailoken', 'Pendragon: Sword of His Father', '2008'],
#  ['38',
#   'Nathan Ashton',
#   'Regeanhere',
#   'Pendragon: Sword of His Father',
#   '2008'],
#  ['39',
#   'Andrew Burns',
#   'King Ambrosius',
#   'Pendragon: Sword of His Father',
#   '2008'],
#  ['40', 'Drew Annen', 'Saxon Guard', 'Pendragon: Sword of His Father', '2008'],
#  ['41', 'Bruce Khan', 'Adam', 'The Last Eve', '2005'],
#  ['42', 'Tomiko Lee', 'Fortune Teller', 'The Last Eve', '2005'],
#  ['43', 'Jourdan Lee Khoo', 'Adam', 'The Last Eve', '2005'],
#  ['44', 'Tim Colceri', 'Priest', 'The Last Eve', '2005'],
#  ['45', 'Kelly Hamilton', 'Eve', 'The Last Eve', '2005'],
#  ['46', 'Paula LaBaredas', 'Lilith', 'The Last Eve', '2005'],
#  ['47', 'Stephanie Cheeva', 'Cat', 'The Last Eve', '2005'],
#  ['48', 'Reuben Langdon', 'Blind Swordmen', 'The Last Eve', '2005'],
#  ['49', 'Kerry Wong', 'Monkeyman', 'The Last Eve', '2005'],
#  ['50', 'Freddie Milligan', 'Snake', 'The Last Eve', '2005'],
#  ['51', 'Melanie Jean', 'The Eve', 'The Last Eve', '2005'],
#  ['52', 'Chris Torres', 'Chainman', 'The Last Eve', '2005'],
#  ['53', 'Sarah Backhouse', 'Austrailian Reporter', 'The Last Eve', '2005'],
#  ['54', 'Mary McNeill', 'Mother', 'Purge', '2008'],
#  ['55', 'Mark Arnold', 'Frank', 'Purge', '2008'],
#  ['56', 'Danielle Hagan', 'Joy', 'Purge', '2008'],
#  ['57', 'Andrew Bancroft', 'Jelly Donut', 'Maximum Wage', '2004'],
#  ['58', 'Andrew Barrett', 'Trucker', 'Maximum Wage', '2004'],
#  ['59', 'Paco Romane', 'Bob', 'Maximum Wage', '2004'],
#  ['60', 'Kenny Taylor', 'Hinky Dink', 'Maximum Wage', '2004'],
#  ['61', 'Kid Beyond', 'Sugar Daddy', 'Maximum Wage', '2004'],
#  ['62', 'Lauren Borowsky', 'Donut Ho', 'Maximum Wage', '2004'],
#  ['63', 'Freda Banks', 'Donut Ho', 'Maximum Wage', '2004'],
#  ['64', 'Sam Loeb', '', 'Maximum Wage', '2004'],
#  ['65', 'Andrea Brooks', 'Donut Ho', 'Maximum Wage', '2004'],
#  ['66', 'Zach Slow', '', 'Maximum Wage', '2004'],
#  ['67', 'Cameron Cox', 'Donut Ho', 'Maximum Wage', '2004'],
#  ['68', 'Edward Burns', 'Paulie', 'The Groomsmen', '2006'],
#  ['69', 'John Leguizamo', 'TC', 'The Groomsmen', '2006'],
#  ['70', 'Matthew Lillard', 'Dez Howard', 'The Groomsmen', '2006'],
#  ['71', 'Donal Logue', 'Jimbo', 'The Groomsmen', '2006'],
#  ['72', 'Jay Mohr', 'Cousin Mike Sullivan', 'The Groomsmen', '2006'],
#  ['73', 'Brittany Murphy', 'Sue', 'The Groomsmen', '2006'],
#  ['74', 'Heather Burns', 'Jules', 'The Groomsmen', '2006'],
#  ['75', 'Jessica Capshaw', 'Jen', 'The Groomsmen', '2006'],
#  ['76', 'Joe Pistone', 'Top Cat', 'The Groomsmen', '2006'],
#  ['77', 'Shari Albert', 'Tina Howard', 'The Groomsmen', '2006'],
#  ['78', "John F. O'Donohue", 'Pops', 'The Groomsmen', '2006'],
#  ['79', 'Arthur J. Nascarella', 'Mr. B', 'The Groomsmen', '2006'],
#  ['80', 'Spencer Fox', 'Little Jack', 'The Groomsmen', '2006'],
#  ['81', 'Amy Leonard', 'Crystal', 'The Groomsmen', '2006'],
#  ['82', 'Shelly Dunn', '', 'The J-K Conspiracy', '2004'],
#  ['83', 'Don Rickles', '', 'The J-K Conspiracy', '2004'],
#  ['84', 'Dave Rickards', '', 'The J-K Conspiracy', '2004'],
#  ['85', 'Ken Weiler', '', 'The Karaoke King', '2007'],
#  ['86', 'Anil Kumar', '', 'The Karaoke King', '2007'],
#  ['87', 'Annie Miesels', '', 'The Karaoke King', '2007'],
#  ['88', 'Amanda Clark', '', 'The Karaoke King', '2007'],
#  ['89', 'Keston John', '', 'The Karaoke King', '2007'],
#  ['90', 'Dont? Bonner', '', 'The Karaoke King', '2007'],
#  ['91', 'Sam J. Waters', '', 'The Karaoke King', '2007'],
#  ['92', 'Giancarlo A. Damiani', '', 'The Karaoke King', '2007'],
#  ['93', 'John Archer Lundgren', '', 'The Karaoke King', '2007'],
#  ['94', 'Tom Arnold', 'Bill Williams', 'The Kid &amp; I', '2005'],
#  ['95', 'Shannon Elizabeth', 'Shelby Roman', 'The Kid &amp; I', '2005'],
#  ['96', 'Linda Hamilton', 'Susan Mandeville', 'The Kid &amp; I', '2005'],
#  ['97', 'Richard Edson', '', 'The Kid &amp; I', '2005'],
#  ['98', 'Eric Gores', '', 'The Kid &amp; I', '2005'],
#  ['99', 'Joe Mantegna', '', 'The Kid &amp; I', '2005'],
#  ['100', 'Henry Winkler', 'Johnny Bernstein', 'The Kid &amp; I', '2005'],
#  ['101', 'Brenda Strong', '', 'The Kid &amp; I', '2005'],
#  ['102', 'Arielle Kebbel', 'Arielle', 'The Kid &amp; I', '2005'],
#  ['103', 'Arnold Schwarzenegger', 'Arnold', 'The Kid &amp; I', '2005'],
#  ['104', 'Yvette Nicole Brown', '', 'The Kid &amp; I', '2005'],
#  ['105', 'Jamie Lee Curtis', '', 'The Kid &amp; I', '2005'],
#  ['106', 'Pete Francis Heimbold', '', 'The Last Dispatch', '2005'],
#  ['107', 'Brad Corrigan', '', 'The Last Dispatch', '2005'],
#  ['108',
#   'Noah Wyle',
#   'Flynn Carsen',
#   'The Librarian: Quest for the Spear',
#   '2004'],
#  ['109',
#   'Bob Newhart',
#   'Judson',
#   'The Librarian: Quest for the Spear',
#   '2004'],
#  ['110',
#   'Jane Curtin',
#   'Charlene',
#   'The Librarian: Quest for the Spear',
#   '2004'],
#  ['111',
#   'Olympia Dukakis',
#   'Margie Carsen',
#   'The Librarian: Quest for the Spear',
#   '2004'],
#  ['112',
#   'Kyle MacLachlan',
#   'Edward Wilde',
#   'The Librarian: Quest for the Spear',
#   '2004'],
#  ['113',
#   'Sonya Walger',
#   'Nicole Noone',
#   'The Librarian: Quest for the Spear',
#   '2004'],
#  ['114', 'Kelly Hu', 'Lana', 'The Librarian: Quest for the Spear', '2004'],
#  ['115',
#   'Mario Iv?n Mart?nez',
#   'Professor Harris',
#   'The Librarian: Quest for the Spear',
#   '2004'],
#  ['116',
#   'Lisa Brenner',
#   'Debra',
#   'The Librarian: Quest for the Spear',
#   '2004'],
#  ['117',
#   'David Dayan Fisher',
#   'Rhodes',
#   'The Librarian: Quest for the Spear',
#   '2004'],
#  ['118',
#   'Clyde Kusatsu',
#   'Head Monk',
#   'The Librarian: Quest for the Spear',
#   '2004'],
#  ['119',
#   'Alejandra Gollas',
#   'Student #1',
#   'The Librarian: Quest for the Spear',
#   '2004'],
#  ['120',
#   'Terry Scott Taylor',
#   '',
#   "The Making of Mr. Buechner's Dream",
#   '2008'],
#  ['121', 'Tim Chandler', '', "The Making of Mr. Buechner's Dream", '2008'],
#  ['122', 'Greg Flesch', '', "The Making of Mr. Buechner's Dream", '2008'],
#  ['123', 'Ed McTaggart', '', "The Making of Mr. Buechner's Dream", '2008'],
#  ['124', 'John Cena', 'John Triton', 'The Marine', '2006'],
#  ['125', 'Robert Patrick', 'Rome', 'The Marine', '2006'],
#  ['126', 'Kelly Carlson', 'Kate Triton', 'The Marine', '2006'],
#  ['127', 'Drew Powell', 'Joe', 'The Marine', '2006'],
#  ['128', 'Anthony Ray Parker', 'Morgan', 'The Marine', '2006'],
#  ['129', 'Jeff Chase', 'Billy', 'The Marine', '2006'],
#  ['130', 'Manu Bennett', 'Bennett', 'The Marine', '2006'],
#  ['131', 'Robert Coleby', 'Braun', 'The Marine', '2006'],
#  ['132', 'Jerome Ehlers', 'Van Buren', 'The Marine', '2006'],
#  ['133', 'Abigail Bianca', 'Angela', 'The Marine', '2006'],
#  ['134', 'Firass Dirani', 'Al Qaeda Leader', 'The Marine', '2006'],
#  ['135', 'Wesley Snipes', 'Painter', 'The Marksman', '2005'],
#  ['136', 'Tim Abell', 'Lt. Carter', 'The Marksman', '2005'],
#  ['137', 'Emma Samms', 'Amanda Jacks', 'The Marksman', '2005'],
#  ['138', 'William Hope', 'Johnathan Tensor', 'The Marksman', '2005'],
#  ['139', 'Christiaan Haig', 'Hightop', 'The Marksman', '2005'],
#  ['140', 'Anthony Warren', 'Capt. Naish', 'The Marksman', '2005'],
#  ['141', 'Peter Youngblood Hills', 'Hargreaves', 'The Marksman', '2005'],
#  ['142', 'Ryan McCluskey', 'Rodgers', 'The Marksman', '2005'],
#  ['143', 'Warren Derosa', 'Orin', 'The Marksman', '2005'],
#  ['144', 'Serge Soric', 'Andrey Flintov', 'The Marksman', '2005'],
#  ['145', 'Gelu Nitu', 'Minister Viktor Ivanov', 'The Marksman', '2005'],
#  ['146', 'Matt Salinger', 'General Parent', 'The Marksman', '2005'],
#  ['147', 'John Guerrasio', 'Secretary Cummings', 'The Marksman', '2005'],
#  ['148', 'Ian Ashpitel', 'Major Devro', 'The Marksman', '2005'],
#  ['149', 'Dan B?d?r?u', 'Gen. Egor Zaysan', 'The Marksman', '2005'],
#  ['150', 'Peter Swander', 'Sergeant Hill', 'The Marksman', '2005'],
#  ['151', 'Graham Bell', 'Jim', 'The Messengers', '2007'],
#  ['152', 'John Corbett', 'John Rollins', 'The Messengers', '2007'],
#  ['153', 'Michael Daingerfield', 'Police Officer', 'The Messengers', '2007'],
#  ['154', 'William B. Davis', 'Colby Price', 'The Messengers', '2007'],
#  ['155', 'Dylan McDermott', 'Roy', 'The Messengers', '2007'],
#  ['156', 'Penelope Ann Miller', 'Denise', 'The Messengers', '2007'],
#  ['157', 'Dustin Milligan', 'Bobby', 'The Messengers', '2007'],
#  ['158', 'Kristen Stewart', 'Jess', 'The Messengers', '2007'],
#  ['159', 'Jodelle Ferland', 'Michael Rollins', 'The Messengers', '2007'],
#  ['160', 'Brent Briscoe', 'Plume', 'The Messengers', '2007'],
#  ['161', 'Blaine Hart', 'Charlie', 'The Messengers', '2007'],
#  ['162', 'Shirley McQueen', 'Mary Rollins', 'The Messengers', '2007'],
#  ['163', 'Tatiana Maslany', 'Lindsey Rollins', 'The Messengers', '2007'],
#  ['164', 'Evan Turner', 'Ben', 'The Messengers', '2007'],
#  ['165', 'Anna Hagan', 'Doctor', 'The Messengers', '2007'],
#  ['166', 'Kaitlyn McMillan', 'Nurse', 'The Messengers', '2007'],
#  ['167', 'Peter Scoular', 'Deputy', 'The Messengers', '2007'],
#  ['168', 'Don Digiulio', '', 'Dark Harvest', '2004'],
#  ['169', 'Jessica Dunphy', '', 'Dark Harvest', '2004'],
#  ['170', 'Thomas Jay Ryan', '', 'Dream Boy', '2008'],
#  ['171', 'Rickie Lee Jones', '', 'Dream Boy', '2008'],
#  ['172', 'Stephen Bender', '', 'Dream Boy', '2008'],
#  ['173', 'Diana Scarwid', '', 'Dream Boy', '2008'],
#  ['174', 'Rooney Mara', 'Evelyn', 'Dream Boy', '2008'],
#  ['175', 'Randy Wayne', '', 'Dream Boy', '2008'],
#  ['176', 'Owen Beckman', '', 'Dream Boy', '2008'],
#  ['177', 'Maximillian Roeg', '', 'Dream Boy', '2008'],
#  ['178', 'Diarra Kilpatrick', 'Kaleesha', 'Hollywood, je t?aime', '2009'],
#  ['179', 'Jonathan Blanc', 'Gilles', 'Hollywood, je t?aime', '2009'],
#  ['180', 'Eric Debets', 'J?r?me Beaunez', 'Hollywood, je t?aime', '2009'],
#  ['181', 'Chad Allen', 'Ross', 'Hollywood, je t?aime', '2009'],
#  ['182', 'Michael Airington', 'Norma Desire', 'Hollywood, je t?aime', '2009'],
#  ['183', 'Charles Herman-Wurmfeld', 'Thom', 'Hollywood, je t?aime', '2009'],
#  ['184', 'Whitney Anderson', 'Trish', 'Hollywood, je t?aime', '2009'],
#  ['185', 'Sarah Domin', 'Amber Sparks', 'Hollywood, je t?aime', '2009'],
#  ['186', 'Audrey Fiorini', 'Lise Delot', 'Hollywood, je t?aime', '2009'],
#  ['187', 'Randall Bacon', 'Steve Jaspers', 'Hollywood, je t?aime', '2009'],
#  ['188', 'Oscar Alvarez', '', 'Hollywood, je t?aime', '2009'],
#  ['189',
#   'Cesar Arambula',
#   'Trick from Spotlight Bar',
#   'Hollywood, je t?aime',
#   '2009'],
#  ['190', 'Barbie-Q', "Kaleesha's Girlfriend", 'Hollywood, je t?aime', '2009'],
#  ['191',
#   'Jason Boegh',
#   'Commercial Casting Assistant',
#   'Hollywood, je t?aime',
#   '2009'],
#  ['192',
#   'Matthew J Cates',
#   'Immigration Officer',
#   'Hollywood, je t?aime',
#   '2009'],
#  ['193', 'Charles Chen', 'Grip', 'Hollywood, je t?aime', '2009'],
#  ['194',
#   'Charles Chen',
#   'Production Assistant',
#   'Hollywood, je t?aime',
#   '2009'],
#  ['195',
#   'Kelly Ebsary',
#   'Music Video Casting Director',
#   'Hollywood, je t?aime',
#   '2009'],
#  ['196', 'Bruce Wayne Eckelman', 'Traveler', 'Hollywood, je t?aime', '2009'],
#  ['197', 'Mike Endes', 'Paparazzi', 'Hollywood, je t?aime', '2009'],
#  ['198', 'Gabe Fiscale', 'Crew / Art Dept', 'Hollywood, je t?aime', '2009'],
#  ['199',
#   'Mell Flynn',
#   'Commercial Casting Director',
#   'Hollywood, je t?aime',
#   '2009'],
#  ['200', 'Dylan Vox', '', 'Homewrecker', '2009'],
#  ['201', 'Rebekah Kochan', '', 'Homewrecker', '2009'],
#  ['202', 'Lukas Roberts', '', 'Homewrecker', '2009'],
#  ['203', 'Paul Vander Roest', '', 'Homewrecker', '2009'],
#  ['204', 'Peter Szeliga', '', 'Homewrecker', '2009'],
#  ['205', 'Tim Dorian', '', 'Homewrecker', '2009'],
#  ['206', 'Michael Stassi', '', 'Homewrecker', '2009'],
#  ['207', 'Daelen Cory', '', 'Homewrecker', '2009'],
#  ['208', 'Dennis Hurley', 'Whylas', 'The Albino Code', '2006'],
#  ['209', 'Paul DiMilla', 'Curator', 'The Albino Code', '2006'],
#  ['210', 'David Engel', 'Captain Fascist', 'The Albino Code', '2006'],
#  ['211', 'David Arden Engel', 'Captain Fascist', 'The Albino Code', '2006'],
#  ['212', "Mark O'Leary", 'Bob Bangdon', 'The Albino Code', '2006'],
#  ['213', 'Jeffrey Phillips', 'The Preacher', 'The Albino Code', '2006'],
#  ['214', 'Jocelyn S. Neptune', 'Amelie', 'The Albino Code', '2006'],
#  ['215', 'Robert Woo', 'Hooligan 1', 'The Albino Code', '2006'],
#  ['216', 'Giovanni Pantaleo', 'Brother Goldsman', 'The Albino Code', '2006'],
#  ['217', 'Sereivuth Eang', 'Officer Grazer', 'The Albino Code', '2006'],
#  ['218', 'Dan Dow', "Chuck 'Sidekicks' Walker", 'The Albino Code', '2006'],
#  ['219', 'Brian Silliman', 'Officer Howard', 'The Albino Code', '2006'],
#  ['220', 'Alyssa Chamberlain', 'English Girl', 'The Albino Code', '2006'],
#  ['221', 'David Hurley', 'Matrix Twin', 'The Albino Code', '2006'],
#  ['222', 'Ezra Stevens', 'Driver', 'The Albino Code', '2006'],
#  ['223', 'Eric Mill', 'Hooligan 2', 'The Albino Code', '2006'],
#  ['224', 'Robert Mammana', '', 'Just Say Love', '2009'],
#  ['225', 'Bill Humphreys', '', 'Just Say Love', '2009'],
#  ['226', 'Matthew Jaeger', '', 'Just Say Love', '2009'],
#  ['227', "Matt O'Leary", "Brandon O'Leary", 'Anytown', '2009'],
#  ['228', 'Paul Ben-Victor', 'Principal Wheeler', 'Anytown', '2009'],
#  ['229', 'Dan Wells', 'Deputy LeBlanc', 'Anytown', '2009'],
#  ['230', 'Sam Blan', 'Video Executioner', 'Anytown', '2009'],
#  ['231', 'Natasha Henstridge', 'Carol Mills', 'Anytown', '2009'],
#  ['232', 'Jonathan Halyalkar', 'Eric Singh', 'Anytown', '2009'],
#  ['233', 'Sam Murphy', 'Bo Aznabev', 'Anytown', '2009'],
#  ['234', 'Meghan Stansfield', 'Charlotte', 'Anytown', '2009'],
#  ['235', 'Brooke Johnson', 'Michelle', 'Anytown', '2009'],
#  ['236', 'Marshall Allman', 'Mike Grossman', 'Anytown', '2009'],
#  ['237', 'Ross Britz', 'Kyle Castranovo', 'Anytown', '2009'],
#  ['238', 'Natasha Henstridge', 'Carol Mills', 'Anytown', '2009'],
#  ['239', 'Natasha Henstridge', 'Carol Mills', 'Anytown', '2009'],
#  ['240', 'John Savage', 'News producer', 'Anytown', '2009'],
#  ['241',
#   'Matthew Montgomery',
#   'Glenn Phillips',
#   'Long-Term Relationship',
#   '2006'],
#  ['242', 'Windham Beacham', 'Adam Harris', 'Long-Term Relationship', '2006'],
#  ['243', "Artie O'Daly", 'Eli Rosenberg', 'Long-Term Relationship', '2006'],
#  ['244', 'Judy Farrell', 'Diane Harris', 'Long-Term Relationship', '2006'],
#  ['245', 'Joel Bryant', 'Andrew', 'Long-Term Relationship', '2006'],
#  ['246', 'Chuti Tiu', 'Mary Margaret', 'Long-Term Relationship', '2006'],
#  ['247', 'Joe Bratcher', 'William Harris', 'Long-Term Relationship', '2006'],
#  ['248', 'Jeremy Lucas', 'Vincent', 'Long-Term Relationship', '2006'],
#  ['249', 'Bret Wolfe', 'Rex', 'Long-Term Relationship', '2006'],
#  ['250', 'Kelly Keaton', "Eli's boss", 'Long-Term Relationship', '2006'],
#  ['251', 'David Pavao', 'Waiter', 'Long-Term Relationship', '2006'],
#  ['252',
#   'Kevin F. Sherry',
#   'Bad Sweater Guy',
#   'Long-Term Relationship',
#   '2006'],
#  ['253', 'John Gabaldon', 'Club Boy', 'Long-Term Relationship', '2006'],
#  ['254', 'Alicia Layvas', 'Hostess', 'Long-Term Relationship', '2006'],
#  ['255', 'Wendy Tilk', 'Caf? Patron', 'Long-Term Relationship', '2006'],
#  ['256', 'Samuel Ball', '', 'Misconceptions', '2008'],
#  ['257', 'Orlando Jones', '', 'Misconceptions', '2008'],
#  ['258', 'A. J. Cook', 'Miranda Bliss', 'Misconceptions', '2008'],
#  ['259', 'David Moscow', '', 'Misconceptions', '2008'],
#  ['260', 'David Sutcliffe', '', 'Misconceptions', '2008'],
#  ['261', 'Sarah Carter', '', 'Misconceptions', '2008'],
#  ['262', "Aerica D'Amaro", '', 'Misconceptions', '2008'],
#  ['263', 'Derek Long', '', '3-Day Weekend', '2008'],
#  ['264', 'Derek Meeker', '', '3-Day Weekend', '2008'],
#  ['265', 'Gaetano Jones', '', '3-Day Weekend', '2008'],
#  ['266', 'Daniel Rhyder', '', '3-Day Weekend', '2008'],
#  ['267', 'Stephen Twardokus', '', '3-Day Weekend', '2008'],
#  ['268', 'Keena Ferguson', 'Angelica', 'Consinsual', '2010'],
#  ['269', 'Robert Joseph', 'Devon', 'Consinsual', '2010'],
#  ['270', 'Bryan Keith', 'Dillon', 'Consinsual', '2010'],
#  ['271', 'Siaka Massaquoi', 'Terrence', 'Consinsual', '2010'],
#  ['272', 'Kathryn Taylor', 'Jasmine', 'Consinsual', '2010'],
#  ['273', 'Leonard L. Thomas', 'Detective Edwards', 'Consinsual', '2010'],
#  ['274', 'Alexis Zibolis', 'Tara', 'Consinsual', '2010'],
#  ['275', 'Konstantina Mallios', '', 'Tiny Little Lies', '2008'],
#  ['276', 'Hillary Crouse', '', 'Tiny Little Lies', '2008'],
#  ['277', 'Thomas Woolen', '', 'Tiny Little Lies', '2008'],
#  ['278', 'Jaclyn Kerhulas', '', 'Tiny Little Lies', '2008'],
#  ['279', 'Christopher Woolen', '', 'Tiny Little Lies', '2008'],
#  ['280', 'Lenise Sor?n', '', 'Tiny Little Lies', '2008'],
#  ['281', 'George Sharperson', '', 'Tiny Little Lies', '2008'],
#  ['282', 'Drew Berenc', '', 'Tiny Little Lies', '2008'],
#  ['283', 'John Thaddeus', '', 'Tiny Little Lies', '2008'],
#  ['284', 'J. Randolph Harrison', '', 'Tiny Little Lies', '2008'],
#  ['285', 'Chris Shields', 'Robot #1', 'Machines of the Working Class', '2010'],
#  ['286',
#   'Diego Kontarovsky',
#   'Robot #2',
#   'Machines of the Working Class',
#   '2010'],
#  ['287', 'David Krumholtz', '', 'My Suicidal Sweetheart', '2005'],
#  ['288', 'Rosanna Arquette', 'Vera', 'My Suicidal Sweetheart', '2005'],
#  ['289', 'Lorraine Bracco', 'Sheila', 'My Suicidal Sweetheart', '2005'],
#  ['290', 'David Paymer', '', 'My Suicidal Sweetheart', '2005'],
#  ['291', 'Natasha Lyonne', 'Grace', 'My Suicidal Sweetheart', '2005'],
#  ['292', 'Tim Blake Nelson', '', 'My Suicidal Sweetheart', '2005'],
#  ['293', 'Tom Shillue', '', 'My Suicidal Sweetheart', '2005'],
#  ['294', 'Yoel Bercovici', 'Rony', 'Acn?', '2008'],
#  ['295', 'Alejandro Tocar', 'Rafael Bregman', 'Acn?', '2008'],
#  ['296', 'Igal Label', 'Andy Rosenberg', 'Acn?', '2008'],
#  ['297', 'Bel?n Pouchan', 'Nicole Weiss', 'Acn?', '2008'],
#  ['298', 'Gustavo Melnik', 'Sim?n Bregman', 'Acn?', '2008'],
#  ['299', 'Veronica Perrotta', 'Ang?lica', 'Acn?', '2008'],
#  ['300', 'Nestor Guzzini', 'Padre de Andy', 'Acn?', '2008'],
#  ['301', 'Ana Julia Catala', 'Eva Bregman', 'Acn?', '2008'],
#  ['302', 'David Blankleider', 'Martin Bregman', 'Acn?', '2008'],
#  ['303', 'Laura Piperno', 'Naty Bregman', 'Acn?', '2008'],
#  ['304', 'Graciana Albertoni', 'Kioskera', 'Acn?', '2008'],
#  ['305', 'Jenny Goldstein', 'Cosmet?loga', 'Acn?', '2008'],
#  ['306', 'Joseph Gordon-Levitt', 'Bert Rodriguez', 'Elektra Luxx', '2010'],
#  ['307', 'Malin ?kerman', 'Trixie', 'Elektra Luxx', '2010'],
#  ['308', 'Timothy Olyphant', 'Dellwood Butterworth', 'Elektra Luxx', '2010'],
#  ['309', 'Adrianne Palicki', 'Holly Rocket', 'Elektra Luxx', '2010'],
#  ['310', 'Carla Gugino', 'Elektra Luxx', 'Elektra Luxx', '2010'],
#  ['311', 'Ermahn Ospina', 'Jimmy Cojones', 'Elektra Luxx', '2010'],
#  ['312', 'Amy Rosoff', 'Olive Rodriguez', 'Elektra Luxx', '2010'],
#  ['313', 'Kathleen Quinlan', 'Rebecca Linbrook', 'Elektra Luxx', '2010'],
#  ['314', 'Justin Kirk', 'Benjamin', 'Elektra Luxx', '2010'],
#  ['315', 'Susie Goliti', 'Maria', 'Elektra Luxx', '2010'],
#  ['316', 'Marley Shelton', 'Cora', 'Elektra Luxx', '2010'],
#  ['317', 'Lucy Punch', 'Dolores', 'Elektra Luxx', '2010'],
#  ['318', 'Melissa Stephens', 'Nadine', 'Elektra Luxx', '2010'],
#  ['319', 'Emmanuelle Chriqui', 'Bambi Lindberg', 'Elektra Luxx', '2010'],
#  ['320', 'Patrick Caberty', 'Thief #2', 'Elektra Luxx', '2010'],
#  ['321', 'Jake Hames', 'Thief #1', 'Elektra Luxx', '2010'],
#  ['322', 'Isabella Gutierrez', 'Charlotte', 'Elektra Luxx', '2010'],
#  ['323', 'Julianne Moore', 'Mary', 'Elektra Luxx', '2010'],
#  ['324', 'Michael Copon', 'Lamberto', 'Elektra Luxx', '2010'],
#  ['325', 'Vincent Kartheiser', 'Jimmy', 'Elektra Luxx', '2010'],
#  ['326', 'Jesse Garcia', 'Camilo', 'Elektra Luxx', '2010'],
#  ['327', 'John Colella', 'George', 'Elektra Luxx', '2010'],
#  ['328', 'Matt Gerald', 'Michael Ortiz', 'Elektra Luxx', '2010'],
#  ['329', 'Gabriel Gutierrez', 'The Walton Kid', 'Elektra Luxx', '2010'],
#  ['330', 'Traci Dinwiddie', 'Madeline', 'Elektra Luxx', '2010'],
#  ['331', 'Christine Lakin', 'Venus Azucar', 'Elektra Luxx', '2010'],
#  ['332', 'Cale Finot', 'Sy Maplewood', 'Elektra Luxx', '2010'],
#  ['333', 'Melissa Ordway', 'Sabrina Capri', 'Elektra Luxx', '2010'],
#  ['334', 'Emma Bell', 'Eleanore Linbrook', 'Elektra Luxx', '2010'],
#  ['335', 'Carla Gugino', 'Celia', 'Elektra Luxx', '2010'],
#  ['336', 'Aswad Ali', 'Club Patron', 'Elektra Luxx', '2010'],
#  ['337', 'Rya Kihlstedt', 'Rita', 'Elektra Luxx', '2010'],
#  ['338', 'Eric Stoltz', "Dolores Josephine's fianc?", 'Elektra Luxx', '2010'],
#  ['339',
#   'Batman',
#   'Hello Beautiful/Handsome',
#   'The Pleasure of Being Robbed',
#   '2008'],
#  ['340',
#   'Alex Billig',
#   'Trumpet Player',
#   'The Pleasure of Being Robbed',
#   '2008'],
#  ['341', 'Wayne Chin', 'Wayne', 'The Pleasure of Being Robbed', '2008'],
#  ['342',
#   'Jerry Damons',
#   'Jerry The Cop',
#   'The Pleasure of Being Robbed',
#   '2008'],
#  ['343', 'Lowell the Dog', 'Lowell', 'The Pleasure of Being Robbed', '2008'],
#  ['344',
#   'John Dwyer',
#   'Drinks For Everybody',
#   'The Pleasure of Being Robbed',
#   '2008'],
#  ['345', 'The Fly', 'Fly', 'The Pleasure of Being Robbed', '2008'],
#  ['346', 'Dawn Glickman', 'Dawn', 'The Pleasure of Being Robbed', '2008'],
#  ['347', 'Alex Greenblatt', 'Son', 'The Pleasure of Being Robbed', '2008'],
#  ['348', 'Gary Greenblatt', 'Father', 'The Pleasure of Being Robbed', '2008'],
#  ['349',
#   'El?onore Hendricks',
#   'El?onore',
#   'The Pleasure of Being Robbed',
#   '2008'],
#  ['350', 'Francesca LaPrelle', 'Mom', 'The Pleasure of Being Robbed', '2008'],
#  ['351',
#   'Miranda LaPrelle',
#   'Daughter',
#   'The Pleasure of Being Robbed',
#   '2008'],
#  ['352', 'Astrid Larson', 'Astrid', 'The Pleasure of Being Robbed', '2008'],
#  ['353', 'Sam Lisenco', '', 'The Pleasure of Being Robbed', '2008'],
#  ['354',
#   'Van Neistat',
#   'Animal Harraser',
#   'The Pleasure of Being Robbed',
#   '2008'],
#  ['355',
#   'Eloy Ortega',
#   'Flower/Fruit Stand Attendant',
#   'The Pleasure of Being Robbed',
#   '2008'],
#  ['356',
#   'Charlotte Pinson',
#   'Girlfriend',
#   'The Pleasure of Being Robbed',
#   '2008'],
#  ['357', 'Josh Safdie', 'Josh', 'The Pleasure of Being Robbed', '2008'],
#  ['358',
#   'Ariel Schulman',
#   'Boyfriend',
#   'The Pleasure of Being Robbed',
#   '2008'],
#  ['359', 'Andy Spade', 'Andy', 'The Pleasure of Being Robbed', '2008'],
#  ['360',
#   'Bea Spade',
#   "Andy's Daughter Bea",
#   'The Pleasure of Being Robbed',
#   '2008'],
#  ['361',
#   'Henry Tejada',
#   'Henry the Doorman',
#   'The Pleasure of Being Robbed',
#   '2008'],
#  ['362',
#   'Calvin Wilson',
#   'TA Cashier',
#   'The Pleasure of Being Robbed',
#   '2008'],
#  ['363',
#   'Jordan Zaldez',
#   'Jordan The Cop',
#   'The Pleasure of Being Robbed',
#   '2008'],
#  ['364', 'Kelly Hutchinson', '', 'Slippery Slope', '2006'],
#  ['365', 'Wes Ramsey', '', 'Slippery Slope', '2006'],
#  ['366', 'Jim True-Frost', '', 'Slippery Slope', '2006'],
#  ['367', 'Laila Robins', '', 'Slippery Slope', '2006'],
#  ['368', 'Jerry Grayson', '', 'Slippery Slope', '2006'],
#  ['369', 'Yolonda Ross', '', 'Slippery Slope', '2006'],
#  ['370', 'Dan Fogler', '', 'Slippery Slope', '2006'],
#  ['371', 'Maria Tallchief', '', 'Ballets Russes', '2005'],
#  ['372', 'Irina Baronova', '', 'Ballets Russes', '2005'],
#  ['373', 'Alicia Markova', '', 'Ballets Russes', '2005'],
#  ['374', 'Marian Seldes', 'Narrator', 'Ballets Russes', '2005'],
#  ['375', 'George Zoritch', '', 'Ballets Russes', '2005'],
#  ['376', 'Raquel Castro', 'Carmen', 'Tracks of Color', '2007'],
#  ['377', 'Justin Hartley', 'Arthur Curry', 'Aquaman', '2007'],
#  ['378', 'Adrianne Palicki', 'Nadia/Siren', 'Aquaman', '2007'],
#  ['379', 'Daniella Deutscher', 'Atlanna', 'Aquaman', '2007'],
#  ['380', 'Kenny Johnson', 'Sheriff', 'Aquaman', '2007'],
#  ['381', 'Brett Rice', '', 'Aquaman', '2007'],
#  ['382', 'Ving Rhames', 'McCaffery', 'Aquaman', '2007'],
#  ['383', 'Denise Qui?ones', 'Lt. Rachel Torres', 'Aquaman', '2007'],
#  ['384', 'Rick Peters', 'F. B. I. Agent', 'Aquaman', '2007'],
#  ['385', 'Lou Diamond Phillips', 'Tom Curry', 'Aquaman', '2007'],
#  ['386', 'Amber McDonald', 'Eva', 'Aquaman', '2007'],
#  ['387', 'Hasannudin None', 'Hasan', 'Cahaya', '2012'],
#  ['388', 'Inggrid Amelia', "Cahaya's Friend #1", 'Cahaya', '2012'],
#  ['389', 'Inneke Sepiaherawati', 'Cahaya', 'Cahaya', '2012'],
#  ['390', 'Noaldi?Pristian', 'Glue Boy #1', 'Cahaya', '2012'],
#  ['391', 'Wisnu?Irawan', 'Glue Boy #2', 'Cahaya', '2012'],
#  ['392', 'Kokom?Komalasari', "Cahaya's Friend #2", 'Cahaya', '2012'],
#  ['393', 'Sumini Sriwinarti?Rahmawati', "Hasan's Mother", 'Cahaya', '2012'],
#  ['394', 'Dana Block', '', 'Once Every Day', '2012'],
#  ['395', 'Abby Marianetti', '', 'Once Every Day', '2012'],
#  ['396', 'James Franco', 'Jerry', 'Child of God', '2013'],
#  ['397', 'Tim Blake Nelson', 'Sheriff Fate', 'Child of God', '2013'],
#  ['398', 'Jim Parrack', 'Deputy Cotton', 'Child of God', '2013'],
#  ['399', 'Fallon Goodson', 'Girly', 'Child of God', '2013'],
#  ['400', 'Scott Haze', 'Lester Ballard', 'Child of God', '2013'],
#  ['401', 'Jeremy Ambler', 'Boy With The Rifle', 'Child of God', '2013'],
#  ['402', 'Vince Jolivette', 'Ernest', 'Child of God', '2013'],
#  ['403', 'Brian Lally', 'John Greer', 'Child of God', '2013'],
#  ['404', 'Nina Ljeti', 'Victim #1', 'Child of God', '2013'],
#  ['405', 'Coby Batty', 'Hunter', 'Child of God', '2013'],
#  ['406', 'Anna Kooris', 'Screaming lady', 'Child of God', '2013'],
#  ['407', 'Terrance Huff', 'The Pitchman', 'Child of God', '2013'],
#  ['408', 'Michael Holstine', 'Farmer', 'Child of God', '2013'],
#  ['409', 'Elena McGhee', 'Lady In White', 'Child of God', '2013'],
#  ['410', 'John Holt', 'Preacher', 'Child of God', '2013'],
#  ['411', 'Fred Weller', 'Sean', 'Four Lane Highway', '2005'],
#  ['412', 'Greer Goodman', 'Molly', 'Four Lane Highway', '2005'],
#  ['413', 'Reg Rogers', 'Lyle', 'Four Lane Highway', '2005'],
#  ['414', 'Elizabeth Rodriguez', 'Sasha', 'Four Lane Highway', '2005'],
#  ['415', 'Arthur Aulisi', 'Brian', 'Four Lane Highway', '2005'],
#  ['416', 'Earl Baker Jr.', 'Jeff', 'Four Lane Highway', '2005'],
#  ['417', 'Jeff Branson', 'Andy', 'Four Lane Highway', '2005'],
#  ['418', 'Dana Goodman', 'Karen', 'Four Lane Highway', '2005'],
#  ['419', 'Zandy Hartig', 'Stacey', 'Four Lane Highway', '2005'],
#  ['420', 'Garland Hunter', 'Gallery Owner', 'Four Lane Highway', '2005'],
#  ['421', 'Jasmin St. Claire', 'Lillian Carter', 'Swamp Zombies', '2005'],
#  ['422', 'Dan Severn', 'Police Captain', 'Swamp Zombies', '2005'],
#  ['423', 'The Blue Meanie', 'The Hermit', 'Swamp Zombies', '2005'],
#  ['424', 'Kris Cozzens', 'Larry', 'Swamp Zombies', '2005'],
#  ['425', 'Shannon Solo', 'Dr. Phillips', 'Swamp Zombies', '2005'],
#  ['426', 'Janet Aden', 'Mrs. Stephenson', 'Swamp Zombies', '2005'],
#  ['427', 'Hans Cozzens', 'Officer Hans', 'Swamp Zombies', '2005'],
#  ['428', 'Pamela Sutch', 'Monica', 'Swamp Zombies', '2005'],
#  ['429', 'Monica Picirillo', 'Anna', 'Swamp Zombies', '2005'],
#  ['430', 'Kevin DuMond', 'Agent Schiller', 'Swamp Zombies', '2005'],
#  ['431', 'Priscilla Barnes', 'Sheila', 'Alien 3000', '2004'],
#  ['432', 'Lorenzo Lamas', 'Biggs', 'Alien 3000', '2004'],
#  ['433', 'Phoebe Dollar', 'Phoebe', 'Alien 3000', '2004'],
#  ['434', 'Matt Emery', 'Burke', 'Alien 3000', '2004'],
#  ['435', 'Garrett Clancy', 'Park Ranger Janeway', 'Alien 3000', '2004'],
#  ['436', 'Corbin Timbrook', 'Wilkins', 'Alien 3000', '2004'],
#  ['437', 'Megan Molloy', 'Kate', 'Alien 3000', '2004'],
#  ['438', 'Matt Nespoli', 'Zane', 'Alien 3000', '2004'],
#  ['439', 'Christopher Irwin', 'Scott McCool', 'Alien 3000', '2004'],
#  ['440', 'David Kalamus', 'Lyle', 'Alien 3000', '2004'],
#  ['441', 'Shilo May', 'Carla', 'Alien 3000', '2004'],
#  ['442', 'John Fava', 'Straker', 'Alien 3000', '2004'],
#  ['443', 'Elizabeth Hayden Smith', 'Megan', 'Alien 3000', '2004'],
#  ['444', 'Jesse Janzen', 'Steve', 'Alien 3000', '2004'],
#  ['445', 'Scott Schwartz', 'Joey', 'Alien 3000', '2004'],
#  ['446',
#   'Peter Weibel',
#   '',
#   'Peter Weibel, Rewriter:  Early (Conceptual) Photographs, (Expanded) Films, (Body) Videos and (Contextual) Works: 1964-1975',
#   '2009'],
#  ['447', 'Kiki Sugino', '', 'Magic and Loss', '2011'],
#  ['448', 'Yang Ik-Joon', '', 'Magic and Loss', '2011'],
#  ['449', 'Ewan McGregor', 'Chip Lambert', 'The Corrections', '2012'],
#  ['450', 'Maggie Gyllenhaal', 'Denise Lambert', 'The Corrections', '2012'],
#  ['451', 'Rhys Ifans', '', 'The Corrections', '2012'],
#  ['452', 'Chris Cooper', 'Alfred Lambert', 'The Corrections', '2012'],
#  ['453', 'Greta Gerwig', '', 'The Corrections', '2012'],
#  ['454', 'Dianne Wiest', 'Enid Lambert', 'The Corrections', '2012'],
#  ['455', 'Daisy Tahan', 'Denise Lambert', 'The Corrections', '2012'],
#  ['456', 'Lucas Hedges', 'Chip Lambert', 'The Corrections', '2012'],
#  ['457', 'Frank Deal', 'Science Fair Principal', 'The Corrections', '2012'],
#  ['458', 'Roy Pollack', 'NYC Airport Traveler', 'The Corrections', '2012'],
#  ['459', 'Noel Gugliemi', 'Robert', 'Party Animalz', '2004'],
#  ['460', 'Pablo Santos', 'Caesar', 'Party Animalz', '2004'],
#  ['461', 'Jesse Rodriguez', 'Guy at Pool Party', 'Party Animalz', '2004'],
#  ['462', 'Mario Aguilar Jr.', 'Tony', 'Party Animalz', '2004'],
#  ['463', 'Magi Avila', 'Lupe', 'Party Animalz', '2004'],
#  ['464', 'Jaime Aymerich', 'Enrique', 'Party Animalz', '2004'],
#  ['465', 'Chris Caldovino', 'Officer Ray Cyst', 'Party Animalz', '2004'],
#  ['466', 'Brad Chance', 'Officer Hobbs', 'Party Animalz', '2004'],
#  ['467', 'Gina DeVettori', 'Female Realtor', 'Party Animalz', '2004'],
#  ['468', 'Kimberly Fisher', 'Burro girl', 'Party Animalz', '2004'],
#  ['469', 'Lil Rob', 'Weed Delivery Guy', 'Party Animalz', '2004'],
#  ['470', 'Rolando Molina', 'Chewi', 'Party Animalz', '2004'],
#  ['471', 'Jonny Moseley', '', "Warren Miller's Dynasty", '2009'],
#  ['472', 'Suhasini Mulay', '', 'Hope and a Little Sugar', '2006'],
#  ['473', 'Anupam Kher', '', 'Hope and a Little Sugar', '2006'],
#  ['474', 'Vikram Chatwal', '', 'Hope and a Little Sugar', '2006'],
#  ['475', 'Amit Sial', '', 'Hope and a Little Sugar', '2006'],
#  ['476', 'Hugh Dillon', '', 'Hope and a Little Sugar', '2006'],
#  ['477', 'Mahima Chaudhry', 'Saloni', 'Hope and a Little Sugar', '2006'],
#  ['478', 'Nicole Gale Anderson', 'Hope Plotnick', 'Mean Girls 2', '2011'],
#  ['479',
#   'Meaghan Jette Martin',
#   "Johanna 'Jo' Mitchell",
#   'Mean Girls 2',
#   '2011'],
#  ['480', 'Amber Wallace', 'Violet', 'Mean Girls 2', '2011'],
#  ['481', 'Jennifer Stone', 'Abby Hanover', 'Mean Girls 2', '2011'],
#  ['482', 'Maiara Walsh', 'Mandi Weatherly', 'Mean Girls 2', '2011'],
#  ['483', 'Diego Boneta', 'Tyler Adams', 'Mean Girls 2', '2011'],
#  ['484', 'Linden Ashby', 'Rod Mitchell', 'Mean Girls 2', '2011'],
#  ['485', 'Tim Meadows', 'Principal Duvall', 'Mean Girls 2', '2011'],
#  ['486', 'Claire Holt', 'Chastity Meyer', 'Mean Girls 2', '2011'],
#  ['487', 'Bethany Anne Lind', 'Quinn Shinn', 'Mean Girls 2', '2011'],
#  ['488', 'Lil Bit', 'Coco Chanel', 'Mean Girls 2', '2011'],
#  ['489', 'Donn Lamkin', 'Sidney Hanover', 'Mean Girls 2', '2011'],
#  ['490', 'Dan Coleman', 'Mr. Winkle', 'Mean Girls 2', '2011'],
#  ['491', 'Patrick Johnson', "Nick 'Big Z' Zimmer", 'Mean Girls 2', '2011'],
#  ['492', 'Colin Dennard', 'Elliott Gold', 'Mean Girls 2', '2011'],
#  ['493', 'Mike Pniewski', 'Mr. Giamatti', 'Mean Girls 2', '2011'],
#  ['494', 'Rhoda Griffis', 'Ilene Hanover', 'Mean Girls 2', '2011'],
#  ['495', 'Juliet Kim', 'Ling', 'Mean Girls 2', '2011'],
#  ['496', 'Willie Larson', 'May', 'Mean Girls 2', '2011'],
#  ['497', 'Greg Perrow', 'Bouncer', 'Mean Girls 2', '2011'],
#  ['498', 'Kimberly Banta', 'Front Desk Secretary', 'Mean Girls 2', '2011'],
#  ['499', 'Rachel Filsoof', 'Cafeteria Girl', 'Mean Girls 2', '2011'],
#  ['500', 'Katelyn E. Bulluck', 'Rugby Girl', 'Mean Girls 2', '2011'],
#  ['501', 'Kelly Gilmore', 'Fifth Year Senior', 'Mean Girls 2', '2011'],
#  ['502', 'Autumn Dial', 'Karate Girl', 'Mean Girls 2', '2011'],
#  ['503', 'Rashad Hawkins', 'Party crew', 'Mean Girls 2', '2011'],
#  ['504', 'Kara Riann Brown', 'Student #1', 'Mean Girls 2', '2011'],
#  ['505', 'Annie Tee', 'Student #2', 'Mean Girls 2', '2011'],
#  ['506', 'Codi Ann Amis', '', 'Mean Girls 2', '2011'],
#  ['507', 'Edward Bryan', 'Police Officer #1', 'Mean Girls 2', '2011'],
#  ['508', 'Tracy Campbell', 'The Jock', 'Mean Girls 2', '2011'],
#  ['509', 'Nilsa Castro', 'Teacher', 'Mean Girls 2', '2011'],
#  ['510', 'Arthur C. Chesser', 'Delivery Man', 'Mean Girls 2', '2011'],
#  ['511', 'Anna Cate Donelan', 'Mandi Weatherly', 'Mean Girls 2', '2011'],
#  ['512', 'Tatum Etheridge', "Johanna 'Jo' Mitchell", 'Mean Girls 2', '2011'],
#  ['513', 'Leah Monet Johnson', 'Dodge ball', 'Mean Girls 2', '2011'],
#  ['514', 'Natalie Murphey', "Johanna 'Jo' Mitchell", 'Mean Girls 2', '2011'],
#  ['515', 'Lyndsay Ricketson', '', 'Mean Girls 2', '2011'],
#  ['516', "Matt O'Toole", 'Drougray', 'Art Thief Musical!', '2004'],
#  ['517', 'Autumn Reeser', 'Clarity', 'Art Thief Musical!', '2004'],
#  ['518', 'Benjamin Sprunger', 'Salvation', 'Art Thief Musical!', '2004'],
#  ['519', 'Sean Smith', 'Aftershave', 'Art Thief Musical!', '2004'],
#  ['520', 'Vanessa VanHartesveldt', 'Chiquie', 'Art Thief Musical!', '2004'],
#  ['521', 'Stephanie Denise Griffin', 'Hottie', 'Art Thief Musical!', '2004'],
#  ['522', 'Jim Blanchette', '1st Detective', 'Art Thief Musical!', '2004'],
#  ['523', 'Anthony Pellegrino', 'Femur', 'Art Thief Musical!', '2004'],
#  ['524', 'Meghan McCormick', 'Baby', 'Art Thief Musical!', '2004'],
#  ['525', 'Andr?a Supnet', 'Sexpot', 'Art Thief Musical!', '2004'],
#  ['526', 'Jeff Pickett', '2nd Detective', 'Art Thief Musical!', '2004'],
#  ['527', 'Jack Wallace', 'Police Chief', 'Art Thief Musical!', '2004'],
#  ['528', 'Richard John Walters', 'Lieutenant', 'Art Thief Musical!', '2004'],
#  ['529', 'Rob Lanza', 'Tall Cop', 'Art Thief Musical!', '2004'],
#  ['530', 'Sasha Williams', 'Cop', 'Art Thief Musical!', '2004'],
#  ['531', 'Jennette McCurdy', 'Lucy Randall', 'See Anthony Run', '2005'],
#  ['532', 'Tom Kenney', '', 'King of the Cage: Unfinished Business', '2005'],
#  ['533', 'Tony Petarra', '', 'King of the Cage: Unfinished Business', '2005'],
#  ['534', '[]', '', 'King of the Cage: Unfinished Business', '2005'],
#  ['535', 'Bobby Gamboa', '', 'King of the Cage: Unfinished Business', '2005'],
#  ['536', 'Ron Cushen', '', 'King of the Cage: Unfinished Business', '2005'],
#  ['537', 'Matthew Underwood', '', 'Kids + money', '2008'],
#  ['538', 'Jay Rodan', 'Burrard Blunt', 'Foxglove', '2008'],
#  ['539', 'Annie Burgstede', 'Virginia West', 'Foxglove', '2008'],
#  ['540', 'Daniel Travis', 'Nick Crippen', 'Foxglove', '2008'],
#  ['541', 'Jet Li', 'Danny', 'Unleashed', '2005'],
#  ['542', 'Bob Hoskins', 'Bart', 'Unleashed', '2005'],
#  ['543', 'Kerry Condon', 'Victoria', 'Unleashed', '2005'],
#  ['544', 'Morgan Freeman', 'Sam', 'Unleashed', '2005'],
#  ['545', 'Vincent Regan', 'Raffles', 'Unleashed', '2005'],
#  ['546', 'Phyllida Law', 'Distinguished Lady', 'Unleashed', '2005'],
#  ['547', 'Tamer Hassan', 'Georgie', 'Unleashed', '2005'],
#  ['548', 'Carole Ann Wilson', 'Maddy', 'Unleashed', '2005'],
#  ['549', 'Michael Jenn', 'Wyeth', 'Unleashed', '2005'],
#  ['550', 'Dylan Brown', 'Lefty', 'Unleashed', '2005'],
#  ['551', 'Mike Lambert', 'The Stranger', 'Unleashed', '2005'],
#  ['552', 'Rose McGowan', 'Red Sonja', 'Red Sonja', '2011'],
#  ['553', 'Andre Black Hines', '', 'What Is Green?', '2009'],
#  ['554', 'Marysol Navarro', '', 'What Is Green?', '2009'],
#  ['555', 'Teju Adisa-Farrar', '', 'What Is Green?', '2009'],
#  ['556', 'Moon Bloodgood', 'Beth', 'Bedrooms', '2009'],
#  ['557', 'Jordan Belfi', '', 'Bedrooms', '2009'],
#  ['558', 'Jesse Garcia', '', 'Bedrooms', '2009'],
#  ['559', 'Barry Bostwick', '', 'Bedrooms', '2009'],
#  ['560', 'Xander Berkeley', '', 'Bedrooms', '2009'],
#  ['561', 'Dee Wallace', '', 'Bedrooms', '2009'],
#  ['562', 'Julie Benz', 'Anna', 'Bedrooms', '2009'],
#  ['563', 'Sarah Clarke', '', 'Bedrooms', '2009'],
#  ['564', 'Ellery Sprayberry', '', 'Bedrooms', '2009'],
#  ['565', 'Dylan Sprayberry', '', 'Bedrooms', '2009'],
#  ['566', 'Enn Reitel', '', 'Bedrooms', '2009'],
#  ['567', 'Anton Yelchin', 'Tommy', 'House of D', '2004'],
#  ['568', 'T?a Leoni', 'Mrs. Warshaw', 'House of D', '2004'],
#  ['569', 'Robin Williams', 'Pappass', 'House of D', '2004'],
#  ['570', 'Zelda Rae Williams', 'Melissa', 'House of D', '2004'],
#  ['571', 'David Duchovny', 'Tom Warshaw', 'House of D', '2004'],
#  ['572', 'Erykah Badu', 'Lady / Bernadette', 'House of D', '2004'],
#  ['573', 'Frank Langella', 'Reverand Duncan', 'House of D', '2004'],
#  ['574', 'Orlando Jones', 'Superfly', 'House of D', '2004'],
#  ['575', 'Willie Garson', '', 'House of D', '2004'],
#  ['576', 'Mark Margolis', 'Mr. Pappass', 'House of D', '2004'],
#  ['577', 'Gideon Jacobs', 'Gerard', 'House of D', '2004'],
#  ['578', 'Magali Amadei', 'Coralie Warshaw', 'House of D', '2004'],
#  ['579', 'Harold Cartier', 'Odell Warshaw', 'House of D', '2004'],
#  ['580', 'Olga Sosnovska', 'Simone', 'House of D', '2004'],
#  ['581', 'Claire Lautier', 'Madam Chatquipet', 'House of D', '2004'],
#  ['582', 'Anthony Anderson', 'Malcolm King', "King's Ransom", '2005'],
#  ['583', 'Jay Mohr', 'Corey', "King's Ransom", '2005'],
#  ['584', 'Kellita Smith', 'Renee King', "King's Ransom", '2005'],
#  ['585', 'Nicole Ari Parker', '', "King's Ransom", '2005'],
#  ['586', 'Regina Hall', 'Peaches Clarke', "King's Ransom", '2005'],
#  ['587', 'Loretta Devine', '', "King's Ransom", '2005'],
#  ['588', 'Donald Faison', 'Andre', "King's Ransom", '2005'],
#  ['589', 'Leila Arcieri', '', "King's Ransom", '2005'],
#  ['590', 'Charlie Murphy', 'Herb Clarke', "King's Ransom", '2005'],
#  ['591', "Brooke D'Orsay", '', "King's Ransom", '2005'],
#  ['592', 'Roger Cross', '', "King's Ransom", '2005'],
#  ['593', 'Carmen Electra', '', 'Full of It', '2007'],
#  ['594', 'Craig Kilborn', 'Mike Hanbo', 'Full of It', '2007'],
#  ['595', 'Teri Polo', 'Mrs. Moran', 'Full of It', '2007'],
#  ['596', 'Kate Mara', 'Annie Dray', 'Full of It', '2007'],
#  ['597', 'Ryan Pinkston', 'Sam Leonard', 'Full of It', '2007'],
#  ['598', 'Joshua Close', 'Kyle Plunkett', 'Full of It', '2007'],
#  ['599', 'Cynthia Stevenson', 'Mrs. Leonard', 'Full of It', '2007'],
#  ['600', 'Derek McGrath', 'Principal Hayes', 'Full of It', '2007'],
#  ['601', 'John Carroll Lynch', 'Mr. Leonard', 'Full of It', '2007'],
#  ['602', 'Amanda Walsh', 'Vicki Sanders', 'Full of It', '2007'],
#  ['603', 'Martin Trudel', 'Mr. Moran', 'Full of It', '2007'],
#  ['604', 'Matt Gordon', 'Coach Henderson', 'Full of It', '2007'],
#  ['605', 'Dane Cook', '', 'Dane Cook: Vicious Circle', '2006'],
#  ['606', 'Alexa Vega', 'Shilo Wallace', 'Repo! The Genetic Opera', '2008'],
#  ['607', 'Paris Hilton', 'Amber Sweet', 'Repo! The Genetic Opera', '2008'],
#  ['608', 'Bill Moseley', 'Luigi Largo', 'Repo! The Genetic Opera', '2008'],
#  ['609', 'Paul Sorvino', 'Rotti Largo', 'Repo! The Genetic Opera', '2008'],
#  ['610',
#   'Anthony Stewart Head',
#   'Nathan Wallace',
#   'Repo! The Genetic Opera',
#   '2008'],
#  ['611', 'Nivek Ogre', 'Pavi Largo', 'Repo! The Genetic Opera', '2008'],
#  ['612',
#   'Terrance Zdunich',
#   'Grave-Robber',
#   'Repo! The Genetic Opera',
#   '2008'],
#  ['613', 'Sarah Brightman', 'Blind Mag', 'Repo! The Genetic Opera', '2008'],
#  ['614', 'Sarah Power', 'Marni', 'Repo! The Genetic Opera', '2008'],
#  ['615', 'Jessica Horn', 'Jessica Adams', 'Repo! The Genetic Opera', '2008'],
#  ['616',
#   'Branko Lebar',
#   "Rotti's Chauffeur",
#   'Repo! The Genetic Opera',
#   '2008'],
#  ['617',
#   'Brianna Buckmaster',
#   'Sherrie Alviso',
#   'Repo! The Genetic Opera',
#   '2008'],
#  ['618',
#   'Anna Kostan',
#   'Young Mormon Woman',
#   'Repo! The Genetic Opera',
#   '2008'],
#  ['619', 'Marty Adams', 'Big Man', 'Repo! The Genetic Opera', '2008'],
#  ['620',
#   'Rebecca Marshall',
#   'Woman with Martini Glass',
#   'Repo! The Genetic Opera',
#   '2008'],
#  ['621', 'Egidio Tari', 'Man In Tuxedo', 'Repo! The Genetic Opera', '2008'],
#  ['622', 'Jake Reardon', 'Single Mother', 'Repo! The Genetic Opera', '2008'],
#  ['623',
#   'J. Larose',
#   'Geneco Spokesperson',
#   'Repo! The Genetic Opera',
#   '2008'],
#  ['624',
#   'John Joseph Gallagher',
#   'Talking Head #1',
#   'Repo! The Genetic Opera',
#   '2008'],
#  ['625',
#   'Andreja Punkris',
#   "Rotti's Henchwoman #1",
#   'Repo! The Genetic Opera',
#   '2008'],
#  ['626', 'Sarah Shahi', 'Salwah', 'AmericanEast', '2007'],
#  ['627', 'Tony Shalhoub', '', 'AmericanEast', '2007'],
#  ['628', 'Christopher Carley', '', 'AmericanEast', '2007'],
#  ['629', 'Anthony Azizi', '', 'AmericanEast', '2007'],
#  ['630', 'Erick Avari', '', 'AmericanEast', '2007'],
#  ['631', 'Sayed Badreya', '', 'AmericanEast', '2007'],
#  ['632', 'Tim Guinee', '', 'AmericanEast', '2007'],
#  ['633', 'Michael Bretten', '', 'AmericanEast', '2007'],
#  ['634', 'Mark Daniel Cade', '', 'AmericanEast', '2007'],
#  ['635', 'Mike Batayeh', '', 'AmericanEast', '2007'],
#  ['636', 'Tay Blessey', '', 'AmericanEast', '2007'],
#  ['637', 'Sammy Sheik', '', 'AmericanEast', '2007'],
#  ['638', 'Joe Torry', '', 'Redrum', '2007'],
#  ['639', 'Jenifer Lewis', '', 'Redrum', '2007'],
#  ['640', 'Jill Marie Jones', '', 'Redrum', '2007'],
#  ['641', 'Chris Spencer', '', 'Redrum', '2007'],
#  ['642', 'Reginald Ballard', '', 'Redrum', '2007'],
#  ['643', 'Terri J. Vaughn', '', 'Redrum', '2007'],
#  ['644', 'Rodney Perry', '', 'Redrum', '2007'],
#  ['645', 'Kenny Young', '', 'Redrum', '2007'],
#  ['646',
#   'Gena Rowlands',
#   'Melissa Eisenbloom',
#   'What If God Were the Sun?',
#   '2007'],
#  ['647',
#   'Lacey Chabert',
#   'Jamie Spagnoletti',
#   'What If God Were the Sun?',
#   '2007'],
#  ['648', 'Klea Scott', '', 'What If God Were the Sun?', '2007'],
#  ['649', 'Sam Trammell', 'Jeff', 'What If God Were the Sun?', '2007'],
#  ['650', 'Kim Roberts', '', 'What If God Were the Sun?', '2007'],
#  ['651', 'Wayne Nicklas', '', 'What If God Were the Sun?', '2007'],
#  ['652', 'Sarah Rafferty', '', 'What If God Were the Sun?', '2007'],
#  ['653', 'Jan Skene', '', 'What If God Were the Sun?', '2007'],
#  ['654', 'Diana Reis', '', 'What If God Were the Sun?', '2007'],
#  ['655', 'Maria Ricossa', '', 'What If God Were the Sun?', '2007'],
#  ['656', 'Master P', '', "Don't Be Scared", '2006'],
#  ['657', 'Lil Romeo', '', "Don't Be Scared", '2006'],
#  ['658', 'Jasmine Bazinet-Phillips', 'Courtney', 'Hamilton', '2006'],
#  ['659', 'Gina Christine Mooers', 'Linda', 'Hamilton', '2006'],
#  ['660', 'Stephanie Vizzi', 'Lena', 'Hamilton', '2006'],
#  ['661', 'Tiffany Boone', 'Briana', 'Hamilton', '2006'],
#  ['662', 'Sarah Seipp-Williams', 'Candace', 'Hamilton', '2006'],
#  ['663', 'Christopher H. Myers', 'Joe', 'Hamilton', '2006'],
#  ['664', 'Megan Clark', 'April', 'Hamilton', '2006'],
#  ['665', 'Madeleine Saar Reeser', 'Adeline', 'Hamilton', '2006'],
#  ['666', 'Marie Collins', 'Marie', 'Hamilton', '2006'],
#  ['667', 'Sara Jane Gerrish', 'Vicky', 'Hamilton', '2006'],
#  ['668', 'Lil Kev', '', 'EZ Money', '2005'],
#  ['669', 'Terri Mann', '', 'EZ Money', '2005'],
#  ['670', 'Emma Kinghorn', '', 'EZ Money', '2005'],
#  ['671', 'Molly Hall', '', 'EZ Money', '2005'],
#  ['672', 'Jonas Gustavson', '', 'EZ Money', '2005'],
#  ['673', 'Melanie Ginnett', '', 'Night', '2006'],
#  ['674', 'Kim Deal', '', 'LoudQUIETloud: A Film About the Pixies', '2006'],
#  ['675',
#   'Joey Santiago',
#   '',
#   'LoudQUIETloud: A Film About the Pixies',
#   '2006'],
#  ['676',
#   'David Lovering',
#   '',
#   'LoudQUIETloud: A Film About the Pixies',
#   '2006'],
#  ['677',
#   'Black Francis',
#   '',
#   'LoudQUIETloud: A Film About the Pixies',
#   '2006'],
#  ['678', 'Kelley Deal', '', 'LoudQUIETloud: A Film About the Pixies', '2006'],
#  ['679', 'Herschell Gordon Lewis', '', 'Horror Business', '2006'],
#  ['680', 'Sid Haig', '', 'Horror Business', '2006'],
#  ['681', 'David Gebroe', '', 'Horror Business', '2006'],
#  ['682', 'Mark Borchardt', '', 'Horror Business', '2006'],
#  ['683',
#   'Carl Christman',
#   '',
#   "Freedom Fries: And Other Stupidity We'll Have to Explain to Our Grandchildren",
#   '2005'],
#  ['684', 'Nina Yuen', '', 'Juanita', '2011'],
#  ['685', 'Jennifer Missoni', '', 'Missoni', '2010'],
#  ['686', 'Margherita Missoni', '', 'Missoni', '2010'],
#  ['687', 'Francesco Maccapni Missoni', '', 'Missoni', '2010'],
#  ['688', 'Vittorio Missoni', '', 'Missoni', '2010'],
#  ['689', 'John Doyel', '', 'Pro-Trusion', '2011'],
#  ['690', 'Sara Colangelo', '', 'Pro-Trusion', '2011'],
#  ['691', 'Alec Tibaldi', '', 'Pro-Trusion', '2011'],
#  ['692',
#   'Jurnee Smollett',
#   'Judith',
#   'Temptation: Confessions of a Marriage Counselor',
#   '2013'],
#  ['693',
#   'Kim Kardashian',
#   'Ava',
#   'Temptation: Confessions of a Marriage Counselor',
#   '2013'],
#  ['694',
#   'Lance Gross',
#   'Brice',
#   'Temptation: Confessions of a Marriage Counselor',
#   '2013'],
#  ['695',
#   'Brandy Norwood',
#   'Melinda',
#   'Temptation: Confessions of a Marriage Counselor',
#   '2013'],
#  ['696',
#   'Eric West',
#   '',
#   'Temptation: Confessions of a Marriage Counselor',
#   '2013'],
#  ['697',
#   'Vanessa L. Williams',
#   'Janice',
#   'Temptation: Confessions of a Marriage Counselor',
#   '2013'],
#  ['698',
#   'Nickolas Wolf',
#   'Church Attendant',
#   'Temptation: Confessions of a Marriage Counselor',
#   '2013'],
#  ['699',
#   'Andrea Moore',
#   'Lisa',
#   'Temptation: Confessions of a Marriage Counselor',
#   '2013'],
#  ['700',
#   'Robbie Jones',
#   '',
#   'Temptation: Confessions of a Marriage Counselor',
#   '2013'],
#  ['701',
#   'Ella Joyce',
#   'Sarah',
#   'Temptation: Confessions of a Marriage Counselor',
#   '2013'],
#  ['702',
#   'Sharon Oliphant',
#   'Receptionist',
#   'Temptation: Confessions of a Marriage Counselor',
#   '2013'],
#  ['703',
#   'Candice Coke',
#   '',
#   'Temptation: Confessions of a Marriage Counselor',
#   '2013'],
#  ['704',
#   'Andrew R. Kaplan',
#   'Board Member',
#   'Temptation: Confessions of a Marriage Counselor',
#   '2013'],
#  ['705',
#   'Zach Sale',
#   'Brad',
#   'Temptation: Confessions of a Marriage Counselor',
#   '2013'],
# ...
#  ['765',
#   'Damian Forest Light',
#   'Court Observer #2',
#   'Atlas Shrugged: Part II',
#   '2012'],
#  ['766',
#   'Damian Forest Light',
#   'Protester #2',
#   'Atlas Shrugged: Part II',
#   '2012'],
#  ['767', 'J.P. Manoux', 'Conductor', 'Atlas Shrugged: Part II', '2012'],
#  ['768', 'Kelly Perine', 'Airport Manager', 'Atlas Shrugged: Part II', '2012'],
#  ['769', 'Ron Rogg?', 'Chauffeur', 'Atlas Shrugged: Part II', '2012'],
#  ['770',
#   'Angelo Romanelli',
#   'Bike Messenger',
#   'Atlas Shrugged: Part II',
#   '2012'],
#  ['771', 'Darren Server', 'Richard Halley', 'Atlas Shrugged: Part II', '2012'],
#  ['772',
#   'Michael James Spall',
#   'Orren Boyle',
#   'Atlas Shrugged: Part II',
#   '2012'],
#  ['773',
#   'Bruce Van Patten',
#   'Board Member',
#   'Atlas Shrugged: Part II',
#   '2012'],
#  ['774', 'Bob Beckel', '', 'Atlas Shrugged: Part II', '2012'],
#  ['775',
#   'Cassandra M. Bellantoni',
#   'Upscale Wedding Guest',
#   'Atlas Shrugged: Part II',
#   '2012'],
#  ['776', 'Sean Hannity', '', 'Atlas Shrugged: Part II', '2012'],
#  ['777', 'Tamara Holder', '', 'Atlas Shrugged: Part II', '2012'],
#  ['778',
#   'Steve Kaufmann',
#   'Person in train station',
#   'Atlas Shrugged: Part II',
#   '2012'],
#  ['779',
#   'Mike Jerome Putnam',
#   'Lead Councel',
#   'Atlas Shrugged: Part II',
#   '2012'],
#  ['780', 'Juan Williams', '', 'Atlas Shrugged: Part II', '2012'],
#  ['781', 'Fred Sokolow', '', 'Fred Sokolow: Gershwin Songbook', '2004'],
#  ['782', 'Dean Lister', '', 'King of the Cage: Renegade', '2005'],
#  ['783', 'Ronald Jhun', '', 'King of the Cage: Renegade', '2005'],
#  ['784', 'Thomas Denny', '', 'King of the Cage: Renegade', '2005'],
#  ['785', 'Charlie Valencia', '', 'King of the Cage: Renegade', '2005'],
#  ['786', 'Greg Mayer', '', 'King of the Cage: Renegade', '2005'],
#  ['787', 'Jason Dolder', '', 'King of the Cage: Renegade', '2005'],
#  ['788', 'John Alessio', '', 'King of the Cage: Renegade', '2005'],
#  ['789', 'Buddy Guy', '', "Buddy Guy: Teachin' the Blues", '2005'],
#  ['790',
#   'David Pollack',
#   '',
#   'Bengals: 2005 Draft Picks Collegiate Highlights',
#   '2005'],
#  ['791',
#   'Chris Henry',
#   '',
#   'Bengals: 2005 Draft Picks Collegiate Highlights',
#   '2005'],
#  ['792',
#   'John Carpenter',
#   '',
#   'Tales from the Crypt: From Comic Books to Television',
#   '2005'],
#  ['793',
#   'R. L. Stine',
#   '',
#   'Tales from the Crypt: From Comic Books to Television',
#   '2005'],
#  ['794',
#   'George A. Romero',
#   '',
#   'Tales from the Crypt: From Comic Books to Television',
#   '2005'],
#  ['795', 'Michael Olajide', '', 'Everlast Boxing Workout: Beginner', '2004'],
#  ['796', 'Velizar Binev', '', 'Star Runners', '2009'],
#  ['797', 'Toni Trucks', '', 'Star Runners', '2009'],
#  ['798', 'Connor Trinneer', '', 'Star Runners', '2009'],
#  ['799', 'James Kyson', '', 'Star Runners', '2009'],
#  ['800', 'Mike Johnson', '', 'Star Runners', '2009'],
#  ['801', 'Aja Evans', '', 'Star Runners', '2009'],
#  ['802', 'Nikolai Sotirov', '', 'Star Runners', '2009'],
#  ['803', 'Hristo Mitzkov', '', 'Star Runners', '2009'],
#  ['804', 'Mike Straub', '', 'Star Runners', '2009'],
#  ['805', 'Shelly Varod', '', 'Star Runners', '2009'],
#  ['806', 'Yana Marinova', 'Stark', 'Star Runners', '2009'],
#  ['807', 'Michael Culkin', '', 'Star Runners', '2009'],
#  ['808', 'Green Day', '', 'The Network: Disease Is Punishment', '2004'],
#  ['809', 'P!nk', '', 'Pink: Funhouse Tour: Live in Australia', '2009'],
#  ['810', 'Marcia Barrett', '', 'The Magic of Boney M', '2007'],
#  ['811', 'Reggie Tsiboe', '', 'The Magic of Boney M', '2007'],
#  ['812', 'Maizie Williams', '', 'The Magic of Boney M', '2007'],
#  ['813', 'Bobby Farrell', '', 'The Magic of Boney M', '2007'],
#  ['814', 'Liz Mitchell', '', 'The Magic of Boney M', '2007'],
#  ['815', 'Luenell', '', 'Katt Williams: 9 Lives', '2010'],
#  ['816', 'Red Grant', '', 'Katt Williams: 9 Lives', '2010'],
#  ['817', 'Edge', 'Edge', 'The John Cena Experience', '2010'],
#  ['818',
#   'Armando Estrada',
#   'Armando Alejandro Estrada',
#   'The John Cena Experience',
#   '2010'],
#  ['819', 'Umaga', 'Umaga', 'The John Cena Experience', '2010'],
#  ['820', 'John Layfield', 'JBL', 'The John Cena Experience', '2010'],
#  ['821', 'Triple H', 'Triple H', 'The John Cena Experience', '2010'],
#  ['822', 'Hornswoggle', 'Hornswoggle', 'The John Cena Experience', '2010'],
#  ['823', 'CM Punk', 'Gangster', 'The John Cena Experience', '2010'],
#  ['824', 'Tazz', 'Tazz', 'The John Cena Experience', '2010'],
#  ['825',
#   'The Great Khali',
#   'The Great Khali',
#   'The John Cena Experience',
#   '2010'],
#  ['826', 'Big Show', 'The Big Show', 'The John Cena Experience', '2010'],
#  ['827', 'Katherine Waterston', 'Solange', 'Love Story', '2012'],
#  ['828', 'Walter Gr?msson', 'Baldur', 'Love Story', '2012'],
#  ['829', 'Elva Osk Olafsd?ttir', 'M?ja', 'Love Story', '2012'],
#  ['830', 'Kristj?n Franklin Magn?ss', 'Karl', 'Love Story', '2012'],
#  ['831', 'Brian Allard', 'John', 'Romance', '2012'],
#  ['832', 'Amber Arrigotti', 'Brit', 'Romance', '2012'],
#  ['833', 'Robynn Hayek', 'Mother', 'Romance', '2012'],
#  ['834', 'Rollyn Stafford', 'Friend #1', 'Romance', '2012'],
#  ['835', 'Colton Hartill', 'Cassanova', 'Romance', '2012'],
#  ['836', 'Michael Cahill', "Mother's Boyfriend", 'Romance', '2012'],
#  ['837', 'Lynsee Chapman', 'Girlfriend #1.2', 'Romance', '2012'],
#  ['838', 'Monica Drake', 'Girlfriend #1.3', 'Romance', '2012'],
#  ['839', 'Douglas Elia', 'Romeo #2', 'Romance', '2012'],
#  ['840', 'Adam Farnsworth', 'Friend #2', 'Romance', '2012'],
#  ['841', 'Christina Lark', 'Girlfriend #1', 'Romance', '2012'],
#  ['842', 'Trina Lebrasseuer', 'Sunday School Teacher', 'Romance', '2012'],
#  ['843', 'Christina Miller', 'Nurse', 'Romance', '2012'],
#  ['844', 'Nicholas Padian', 'Baby', 'Romance', '2012'],
#  ['845', 'Edward Stiner', 'Bus Driver', 'Romance', '2012'],
#  ['846', 'Ryan Pratton', 'Philip Cole', 'Table For One', '2012'],
#  ['847', 'Lena Hart', 'Hostess', 'Table For One', '2012'],
#  ['848', 'Monica Barbaro', 'Stella', 'Table For One', '2012'],
#  ['849', 'Liz Anderson', 'Eyeglasses', 'Table For One', '2012'],
#  ['850', 'Mitch Costanza', 'Bartender', 'Table For One', '2012'],
#  ['851', 'Gabriel Koura', 'Business man', 'Table For One', '2012'],
#  ['852', 'Lawrence Radecker', 'The Boss', 'Table For One', '2012'],
#  ['853', 'Craig C. Lewis', 'The Man', 'Table For One', '2012'],
#  ['854', 'Johanna Young', 'Girl on Bus', 'Table For One', '2012'],
#  ['855', 'Skye Burd', 'Ponytail', 'Table For One', '2012'],
#  ['856', 'Chelsea Tavares', '', 'Crush on U', '2007'],
#  ['857', 'Lil Romeo', '', 'Crush on U', '2007'],
#  ['858', 'Forrest Lipton', '', 'Crush on U', '2007'],
#  ['859', 'Gilbert Yvel', '', 'UFC 115: Liddell vs. Franklin', '2010'],
#  ['860', 'Rich Franklin', '', 'UFC 115: Liddell vs. Franklin', '2010'],
#  ['861', 'Martin Kampmann', '', 'UFC 115: Liddell vs. Franklin', '2010'],
#  ['862', 'Chuck Liddell', '', 'UFC 115: Liddell vs. Franklin', '2010'],
#  ['863', 'Diego Sanchez', '', 'UFC 95: Sanchez vs. Stevenson', '2009'],
#  ['864', 'Joe Stevenson', '', 'UFC 95: Sanchez vs. Stevenson', '2009'],
#  ['865', 'Rory Markham', '', 'UFC 95: Sanchez vs. Stevenson', '2009'],
#  ['866', 'Demian Maia', '', 'UFC 95: Sanchez vs. Stevenson', '2009'],
#  ['867', 'Nate Marquardt', '', 'UFC 95: Sanchez vs. Stevenson', '2009'],
#  ['868', 'Terry Etim', '', 'UFC 95: Sanchez vs. Stevenson', '2009'],
#  ['869', 'Dan Hardy', '', 'UFC 95: Sanchez vs. Stevenson', '2009'],
#  ['870', 'Chael Sonnen', '', 'UFC 95: Sanchez vs. Stevenson', '2009'],
#  ['871', 'Wilson Gouveia', '', 'UFC 95: Sanchez vs. Stevenson', '2009'],
#  ['872', 'Brian Cobb', '', 'UFC 95: Sanchez vs. Stevenson', '2009'],
#  ['873', 'Josh Koscheck', '', 'UFC 95: Sanchez vs. Stevenson', '2009'],
#  ['874', 'Troy Mandaloniz', '', 'UFC 95: Sanchez vs. Stevenson', '2009'],
#  ['875', 'Junior dos Santos', '', 'UFC 95: Sanchez vs. Stevenson', '2009'],
#  ['876',
#   'Elton John',
#   '',
#   'Elton John: Elton 60: Live at Madison Square Garden',
#   '2007'],
#  ['877',
#   'Tanya Tucker',
#   '',
#   "Tanya Tucker: Live at Billy Bob's Texas",
#   '2005'],
#  ['878', 'Kelly Richey', '', 'Kelly Richey: Live', '2005'],
#  ['879', 'Rachelle Lefevre', 'Elsa Carter', 'Do You Know Me', '2009'],
#  ['880', 'Lynda Boyd', '', 'Do You Know Me', '2009'],
#  ['881', 'Alvin Sanders', '', 'Do You Know Me', '2009'],
#  ['882', 'Jeremy London', 'Jake Farber', 'Do You Know Me', '2009'],
#  ['883', 'Malcolm Stewart', '', 'Do You Know Me', '2009'],
#  ['884', 'Adrien Dorval', '', 'Do You Know Me', '2009'],
#  ['885', 'Gina Chiarelli', '', 'Do You Know Me', '2009'],
#  ['886', 'Zahf Paroo', '', 'Do You Know Me', '2009'],
#  ['887', 'Ted Whittall', '', 'Do You Know Me', '2009'],
#  ['888', 'Dean Wray', '', 'Do You Know Me', '2009'],
#  ['889', 'Joe Mantegna', '', 'Naked Fear', '2007'],
#  ['890', 'J.D. Garfield', '', 'Naked Fear', '2007'],
#  ['891', 'Ronald Dunas', '', 'Naked Fear', '2007'],
#  ['892', 'Lisa Bonanno', '', 'Naked Fear', '2007'],
#  ['893', 'Danielle De Luca', '', 'Naked Fear', '2007'],
#  ['894', 'Kalila Ceccarelli', '', 'Naked Fear', '2007'],
#  ['895', 'Dennis E. Garber', '', 'Naked Fear', '2007'],
#  ['896', 'Kevin R. Elder', '', 'Naked Fear', '2007'],
#  ['897', 'Lourdez Gonzales', '', 'Naked Fear', '2007'],
#  ['898', 'Evan Adrian', '', 'Naked Fear', '2007'],
#  ['899', 'Clark Sanchez', 'Predator', 'Naked Fear', '2007'],
#  ['900', 'John Macho', 'Bar Patron', 'Naked Fear', '2007'],
#  ['901', 'Thomas Daniel', '', 'The Beverages', '2008'],
#  ['902', 'Scott Michael Adams', '', 'The Beverages', '2008'],
#  ['903', 'Jon Benevenia', '', 'The Beverages', '2008'],
#  ['904', 'Susie Schutt', '', 'The Beverages', '2008'],
#  ['905', 'Gillian Mackay-Smith', '', 'The Beverages', '2008'],
#  ['906', 'Matt Bartle', '', 'The Beverages', '2008'],
#  ['907', 'Tony Barbosa', '', 'The Beverages', '2008'],
#  ['908', 'Adam Henry Garcia', '', 'The Beverages', '2008'],
#  ['909', 'Aden Hakimi', '', 'The Beverages', '2008'],
#  ['910', 'Mar?a Lid?n', '', 'Tell Me Do You Miss Me', '2006'],
#  ['911', 'Mike Inez', '', 'Behind The Player: Mike Inez', '2008'],
#  ['912', 'John Tempesta', '', 'Behind The Player: Mike Inez', '2008'],
#  ['913', 'Mickie James', 'Mickie James', 'WWE: Hell in a Cell 2009', '2009'],
#  ['914', 'Cody Rhodes', '', 'WWE: Hell in a Cell 2009', '2009'],
#  ['915', 'Oscar Gutierrez', '', 'WWE: Hell in a Cell 2009', '2009'],
#  ['916', 'Randy Orton', '', 'WWE: Hell in a Cell 2009', '2009'],
#  ['917', 'CM Punk', '', 'WWE: Hell in a Cell 2009', '2009'],
#  ['918', 'Ted DiBiase, Jr.', '', 'WWE: Hell in a Cell 2009', '2009'],
#  ['919', 'Kofi Kingston', '', 'WWE: Hell in a Cell 2009', '2009'],
#  ['920', 'Triple H', '', 'WWE: Hell in a Cell 2009', '2009'],
#  ['921', 'John Cena', '', 'WWE: Hell in a Cell 2009', '2009'],
#  ['922', 'The Undertaker', '', 'WWE: Hell in a Cell 2009', '2009'],
#  ['923', 'Dolph Ziggler', '', 'WWE: Hell in a Cell 2009', '2009'],
#  ['924', 'Joy Behar', '', 'Mr. Laughs: A Look Behind the Curtain', '2008'],
#  ['925', 'Soupy Sales', '', 'Mr. Laughs: A Look Behind the Curtain', '2008'],
#  ['926',
#   'Julius La Rosa',
#   '',
#   'Mr. Laughs: A Look Behind the Curtain',
#   '2008'],
#  ['927', 'Don Rickles', '', 'Mr. Laughs: A Look Behind the Curtain', '2008'],
#  ['928',
#   'RoseAnn Richards',
#   '',
#   'Mr. Laughs: A Look Behind the Curtain',
#   '2008'],
#  ['929', 'Johnny Dark', '', 'Mr. Laughs: A Look Behind the Curtain', '2008'],
#  ['930', 'Jackie Mason', '', 'Mr. Laughs: A Look Behind the Curtain', '2008'],
#  ['931', 'Sal Richards', '', 'Mr. Laughs: A Look Behind the Curtain', '2008'],
#  ['932', 'Lainie Kazan', '', 'Mr. Laughs: A Look Behind the Curtain', '2008'],
#  ['933', 'Jerry Cardone', '', 'Mr. Laughs: A Look Behind the Curtain', '2008'],
#  ['934', 'Sid Caesar', '', 'Mr. Laughs: A Look Behind the Curtain', '2008'],
#  ['935', 'Norm Crosby', '', 'Mr. Laughs: A Look Behind the Curtain', '2008'],
#  ['936',
#   "Vincent D'Onofrio",
#   '',
#   'Mr. Laughs: A Look Behind the Curtain',
#   '2008'],
#  ['937', 'Fyvush Finkel', '', 'Mr. Laughs: A Look Behind the Curtain', '2008'],
#  ['938',
#   'Mario Van Peebles',
#   '',
#   "Spiritual Liberation: Fulfilling Your Soul's Potential",
#   '2009'],
#  ['939',
#   'Michael Beckwith',
#   '',
#   "Spiritual Liberation: Fulfilling Your Soul's Potential",
#   '2009'],
#  ['940', 'Tamzin Outhwaite', 'Jill Waters', 'Radio Cape Cod', '2008'],
#  ['941', 'O. T. Fagbenle', 'Sunday Umankwe', 'Radio Cape Cod', '2008'],
#  ['942', 'Tamzin Merchant', 'Anna', 'Radio Cape Cod', '2008'],
#  ['943', 'Julian Silver', 'Virgil', 'Radio Cape Cod', '2008'],
#  ['944', 'Debra Wise', 'Alice', 'Radio Cape Cod', '2008'],
#  ['945', 'Justin Adams', 'Jake Ford', 'Radio Cape Cod', '2008'],
#  ['946', 'Ana Kaczmarek', 'Monica', 'Radio Cape Cod', '2008'],
#  ['947', 'Andrew Silver', 'Clay', 'Radio Cape Cod', '2008'],
#  ['948', 'Marta Rainer', 'Eva', 'Radio Cape Cod', '2008'],
#  ['949', 'Helen McCreery', 'Chip Noise', 'Radio Cape Cod', '2008'],
#  ['950', 'Shane West', 'Spc. Jeff Keller', 'Red Sands', '2009'],
#  ['951', 'Callum Blue', '', 'Red Sands', '2009'],
#  ['952', 'Noel Gugliemi', '', 'Red Sands', '2009'],
#  ['953', 'Leonard Roberts', '', 'Red Sands', '2009'],
#  ['954', 'Theo Rossi', '', 'Red Sands', '2009'],
#  ['955', 'Aldis Hodge', '', 'Red Sands', '2009'],
#  ['956', 'J.K. Simmons', 'Lt. Col. Arson', 'Red Sands', '2009'],
#  ['957', 'Brendan Miller', '', 'Red Sands', '2009'],
#  ['958', 'Chris Carter', '', 'Red Sands', '2009'],
#  ['959', 'Mercedes Mas?hn', '', 'Red Sands', '2009'],
#  ['960', 'Sarah Doolan', '', 'Red Sands', '2009'],
#  ['961', 'Jason London', 'Jake Townsend', 'Showdown at Area 51', '2007'],
#  ['962', 'Gigi Edgley', 'Monica Gray', 'Showdown at Area 51', '2007'],
#  ['963', 'Coby Bell', 'Jude', 'Showdown at Area 51', '2007'],
#  ['964', 'Lee Horsley', 'Diamond Joe Carson', 'Showdown at Area 51', '2007'],
#  ['965', 'Christa Campbell', 'Charlie Weise', 'Showdown at Area 51', '2007'],
#  ['966', 'Brock Roberts', 'Maj 12 OP 1', 'Showdown at Area 51', '2007'],
#  ['967', 'Mel Fair', 'Tate', 'Showdown at Area 51', '2007'],
#  ['968', 'Jahidi White', 'Kronnan', 'Showdown at Area 51', '2007'],
#  ['969', 'Kip Martin', 'Alex Townsend', 'Showdown at Area 51', '2007'],
#  ['970', 'Tom Lowell', 'Ranger #1', 'Showdown at Area 51', '2007'],
#  ['971', 'Victor Garber', 'Sinestro', 'Green Lantern: First Flight', '2009'],
#  ['972', 'Michael Madsen', 'Kilowog', 'Green Lantern: First Flight', '2009'],
#  ['973',
#   'Christopher Meloni',
#   'Hal Jordan',
#   'Green Lantern: First Flight',
#   '2009'],
#  ['974',
#   'William Schallert',
#   'Appa Ali Apsa',
#   'Green Lantern: First Flight',
#   '2009'],
#  ['975', 'Kurtwood Smith', 'Kanjar Ro', 'Green Lantern: First Flight', '2009'],
#  ['976',
#   'John Larroquette',
#   'Tomar-Re',
#   'Green Lantern: First Flight',
#   '2009'],
#  ['977', 'Larry Drake', 'Ganthet', 'Green Lantern: First Flight', '2009'],
#  ['978', 'Tricia Helfer', 'Boodikka', 'Green Lantern: First Flight', '2009'],
#  ['979',
#   "Olivia d'Abo",
#   'Carol Ferris',
#   'Green Lantern: First Flight',
#   '2009'],
#  ['980', 'Malachi Throne', 'Ranakar', 'Green Lantern: First Flight', '2009'],
#  ['981',
#   'Richard McGonagle',
#   'Abin Sur',
#   'Green Lantern: First Flight',
#   '2009'],
#  ['982', 'Juliet Landau', 'Labella', 'Green Lantern: First Flight', '2009'],
#  ['983', 'David Lander', "Ch'p", 'Green Lantern: First Flight', '2009'],
#  ['984', 'Richard Green', 'Cuch', 'Green Lantern: First Flight', '2009'],
#  ['985', 'Ken Baumann', 'Mike', "Here's Herbie", '2009'],
#  ['986', 'Chris Coppola', 'Herbie', "Here's Herbie", '2009'],
#  ['987', 'Katy Selverstone', 'Mother', "Here's Herbie", '2009'],
#  ['988', 'Nick Toth', 'Dr. Tollman', "Here's Herbie", '2009'],
#  ['989', 'Matthew Robert Gottlieb', '', "Here's Herbie", '2009'],
#  ['990', 'Jason Connery', '', 'Dragonquest', '2009'],
#  ['991', 'Marc Singer', '', 'Dragonquest', '2009'],
#  ['992', 'Jay Beyers', '', 'Dragonquest', '2009'],
#  ['993', 'Jonathan Nation', '', 'Dragonquest', '2009'],
#  ['994', 'Brian Thompson', '', 'Dragonquest', '2009'],
#  ['995', 'Daniel Bonjour', '', 'Dragonquest', '2009'],
#  ['996', 'Russell Reynolds', '', 'Dragonquest', '2009'],
#  ['997', 'Jennifer Dorogi', '', 'Dragonquest', '2009'],
#  ['998', 'John Harlacher', '', 'Love Simple', '2009'],
#  ['999', 'Patrizia Hernandez', '', 'Love Simple', '2009'],
#  ...]

# %%
import networkx as nx
from networkx.algorithms import bipartite 

actors = [x[1] for x in data]
films = [x[3] for x in data]
actors_uniq = set(actors)
films_uniq = set(films)

G = nx.Graph()

G.add_nodes_from(actors_uniq, bipartite=0)
G.add_nodes_from(films_uniq, bipartite=1)
edges = zip(actors, films)
G.add_edges_from(edges)

# %% [markdown]
# This graph is too large to visualize, so we'll pull a small subgraph to see what the data look like.

# %%
import itertools
import matplotlib.pylab as plt
# %matplotlib nbagg

selection = ['The Great Gatsby', 'The Wolf of Wall Street']
list_of_nodes = []

for film in selection: 
    list_of_nodes.append(nx.neighbors(G, film))

list_of_nodes = list(itertools.chain.from_iterable(list_of_nodes))
[list_of_nodes.append(film) for film in selection]
S = G.subgraph(list_of_nodes)

fig,ax = plt.subplots()
nx.draw_networkx(S, node_size=100, font_size=9)
plt.axis('off')
# Out:
# /usr/local/anaconda/lib/python3.4/site-packages/IPython/kernel/__init__.py:13: ShimWarning: The `IPython.kernel` package has been deprecated. You should import from ipykernel or jupyter_client instead.
#   "You should import from ipykernel or jupyter_client instead.", ShimWarning)
# <img src="data:image/png;base64,...">
# /usr/local/anaconda/lib/python3.4/site-packages/matplotlib/collections.py:650: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   if self._edgecolors_original != str('face'):
# (-1.5, 1.5, -0.80000000000000004, 0.80000000000000004)

# %% [markdown]
# ## The Kevin Bacon game
# OK, let's play the Kevin Bacon game. First, let's see what movies he's been in over the last decade...

# %%
bacon_films = nx.neighbors(G,'Kevin Bacon')
print(bacon_films)
# Out:
# ['Beyond All Boundaries', 'Rails &amp; Ties', 'The Woodsman', 'Saving Angelo', 'Crazy, Stupid, Love.', 'Loverboy', 'Where the Truth Lies', 'My One and Only', 'Super', 'The Magic 7', 'Frost/Nixon', 'Cavedweller', 'R.I.P.D.', 'Going to Pieces: The Rise and Fall of the Slasher Film', "Jayne Mansfield's Car", 'Death Sentence', '8', 'The Air I Breathe', 'X-Men: First Class', 'Taking Chance', 'Forces of Nature']

# %%
actors_list = []
actors_list.append(nx.neighbors(G,'Kevin Bacon'))
for film in nx.neighbors(G,'Kevin Bacon'):
        actors_list.append(nx.neighbors(G,film))

actors_list= list(itertools.chain.from_iterable(actors_list))

# %%
plt.subplots()
S = nx.subgraph(G,actors_list)
nx.draw_networkx(S, node_size=150, font_size=8)
plt.axis('off')

# %% [markdown]
# The computation is very quick. And we can now get the distance from Kevin Bacon to any other actor or movie. Kevin has a distance of 0, of course, and the films he's been in lately are all at distance 0.5. His co-stars in those movies are at distance 1, so they have Kevin Bacon number of 1.
#
# Querying this for another actor is very fast because the result is already computed. Robert De Niro, for example, has a Kevin Bacon number (for the last decade) of 2. There are many paths of length two between these two actors, and 'get_path' will plot one of them.
#
# If we go back to the connected component of Japanese films and pick one of the actors, Yuzuru Fujimoto, we see he has an infinite Kevin Bacon number over the last decade, which fits the earlier result that Yuzuru is in a different component. If we try to find the path between these two actors, we'll get an error.
#
# First, let's find the number of connected components. We'll do this on our bipartite graph with both films and actors, although the groups will be identical when we make an actor social network where edges are weighted according to the number of shared films.

# %%
ccs = nx.connected_component_subgraphs(G)
graphs =list(ccs)

# %%
S0 = nx.Graph(G.subgraph(graphs[0]))
top_nodes = set(n for n,d in S0.nodes(data=True) if d['bipartite']==0)

# %%
Actor_graph = bipartite.projected_graph(G, top_nodes)

# %% [markdown]
# We can find the shortest path distance between every other vertex and Mr. Bacon. Keep in mind that this is a bipartite graph, so movies will have half distances from our target and actors will have whole number distances from the target.
